# %%
from sklearn.model_selection import train_test_split
import numpy as np
from matplotlib import pyplot as plt
 
import tensorflow as tf
 
from tensorflow.python.platform import tf_logging as logging
 
logging.set_verbosity(logging.INFO)
logging.log(logging.INFO, "Tensorflow version " + tf.__version__)
# Out:
# INFO:tensorflow:Tensorflow version 1.10.0

# %%
def generate_time_series(datalen):
    freq1 = 0.2
    freq2 = 0.15
    noise = [np.random.random() * 0.1 for i in range(datalen)]
    x1 = np.sin(np.arange(0, datalen) * freq1) + noise
    x2 = np.sin(np.arange(0, datalen) * freq2) + noise
    x = x1 + x2
    return x.astype(np.float32)
 
 
DATA_SEQ_LEN = 24000
 
data = generate_time_series(DATA_SEQ_LEN)

# %%
data
# fig, ax = plt.subplots(figsize=(20,8))
# plt.plot(data)
# Out:
# array([ 0.19481578,  0.5410025 ,  0.79321164, ..., -1.4565566 ,
#        -1.0588611 , -0.86356205], dtype=float32)

# %%
SEQLEN = 16  # unrolled sequence length
BATCHSIZE = 32
 
X = data
Y = np.roll(data, -1)
 
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.2, random_state=0)
 
X_train = np.reshape(X_train, [-1, SEQLEN])
Y_train = np.reshape(Y_train, [-1, SEQLEN])
 
X_test = np.reshape(X_test, [-1, SEQLEN])
Y_test = np.reshape(Y_test, [-1, SEQLEN])
 
 
def train_dataset():
    dataset = tf.data.Dataset.from_tensor_slices((X_train, Y_train))
    dataset = dataset.repeat()
    dataset = dataset.shuffle(DATA_SEQ_LEN * 4 // SEQLEN)
    dataset = dataset.batch(BATCHSIZE)
    samples, labels = dataset.make_one_shot_iterator().get_next()
    return samples, labels
 
 
def eval_dataset():
    evaldataset = tf.data.Dataset.from_tensor_slices((X_test, Y_test))
    evaldataset = evaldataset.repeat(1)
    evaldataset = evaldataset.batch(BATCHSIZE)
 
    samples, labels = evaldataset.make_one_shot_iterator().get_next()
    return samples, labels

# %%
RNN_CELLSIZE = 80
N_LAYERS = 2
DROPOUT_PKEEP = 0.7
 
def model_rnn_fn(features, labels, mode):
    
    X = tf.expand_dims(features, axis=2)
 
    batchsize = tf.shape(X)[0]
    seqlen = tf.shape(X)[1]
 
    cells = [tf.nn.rnn_cell.GRUCell(RNN_CELLSIZE) for _ in range(N_LAYERS)]
 
    cells[:-1] = [tf.nn.rnn_cell.DropoutWrapper(cell, output_keep_prob=DROPOUT_PKEEP) for cell in cells[:-1]]
    
     # a stacked RNN cell still works like an RNN cell
    cell = tf.nn.rnn_cell.MultiRNNCell(cells, state_is_tuple=False)
 
    # X[BATCHSIZE, SEQLEN, 1], Hin[BATCHSIZE, RNN_CELLSIZE*N_LAYERS]
    Yn, H = tf.nn.dynamic_rnn(cell, X, dtype=tf.float32)
 
    Yn = tf.reshape(Yn, [batchsize * seqlen, RNN_CELLSIZE])
    Yr = tf.layers.dense(Yn, 1)  # Yr [BATCHSIZE*SEQLEN, 1]
    Yr = tf.reshape(Yr, [batchsize, seqlen, 1])  # Yr [BATCHSIZE, SEQLEN, 1]
 
    Yout = Yr[:, -1, :]  # Last output Yout [BATCHSIZE, 1]
 
    loss = train_op = None
    if mode != tf.estimator.ModeKeys.PREDICT:
        labels = tf.expand_dims(labels, axis=2)
        loss = tf.losses.mean_squared_error(Yr, labels)  # la  bels[BATCHSIZE, SEQLEN, 1]
        lr = 0.001
        optimizer = tf.train.AdamOptimizer(learning_rate=lr)
 
        train_op = tf.contrib.training.create_train_op(loss, optimizer)
 
    return tf.estimator.EstimatorSpec(
        mode=mode,
        predictions={"Yout": Yout},
        loss=loss,
        train_op=train_op
    )

# %%
training_config = tf.estimator.RunConfig(model_dir="./outputdir")
estimator = tf.estimator.Estimator(model_fn=model_rnn_fn, config=training_config)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': './outputdir', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000002726282E668>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
estimator.train(input_fn=train_dataset,steps=2000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./outputdir\model.ckpt.
# INFO:tensorflow:loss = 0.97596157, step = 1
# INFO:tensorflow:global_step/sec: 31.4379
# INFO:tensorflow:loss = 0.048873693, step = 101 (3.182 sec)
# INFO:tensorflow:global_step/sec: 37.3906
# INFO:tensorflow:loss = 0.044901073, step = 201 (2.674 sec)
# INFO:tensorflow:global_step/sec: 37.4326
# INFO:tensorflow:loss = 0.050509457, step = 301 (2.672 sec)
# INFO:tensorflow:global_step/sec: 37.3627
# INFO:tensorflow:loss = 0.046989094, step = 401 (2.675 sec)
# INFO:tensorflow:global_step/sec: 37.2931
# INFO:tensorflow:loss = 0.04316484, step = 501 (2.682 sec)
# INFO:tensorflow:global_step/sec: 37.1133
# INFO:tensorflow:loss = 0.043046176, step = 601 (2.693 sec)
# INFO:tensorflow:global_step/sec: 36.9898
# INFO:tensorflow:loss = 0.04390747, step = 701 (2.704 sec)
# INFO:tensorflow:global_step/sec: 37.3209
# INFO:tensorflow:loss = 0.043107726, step = 801 (2.679 sec)
# INFO:tensorflow:global_step/sec: 34.9118
# INFO:tensorflow:loss = 0.042362384, step = 901 (2.865 sec)
# INFO:tensorflow:global_step/sec: 35.2687
# INFO:tensorflow:loss = 0.04413861, step = 1001 (2.833 sec)
# INFO:tensorflow:global_step/sec: 36.3316
# INFO:tensorflow:loss = 0.03992687, step = 1101 (2.752 sec)
# INFO:tensorflow:global_step/sec: 37.072
# INFO:tensorflow:loss = 0.04283853, step = 1201 (2.697 sec)
# INFO:tensorflow:global_step/sec: 37.2931
# INFO:tensorflow:loss = 0.04207063, step = 1301 (2.681 sec)
# INFO:tensorflow:global_step/sec: 36.174
# INFO:tensorflow:loss = 0.04377805, step = 1401 (2.765 sec)
# INFO:tensorflow:global_step/sec: 35.431
# INFO:tensorflow:loss = 0.038767267, step = 1501 (2.822 sec)
# INFO:tensorflow:global_step/sec: 32.8272
# INFO:tensorflow:loss = 0.03998459, step = 1601 (3.046 sec)
# INFO:tensorflow:global_step/sec: 35.8629
# INFO:tensorflow:loss = 0.0441034, step = 1701 (2.787 sec)
# INFO:tensorflow:global_step/sec: 36.9898
# INFO:tensorflow:loss = 0.041009083, step = 1801 (2.703 sec)
# INFO:tensorflow:global_step/sec: 36.7723
# INFO:tensorflow:loss = 0.040713012, step = 1901 (2.720 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into ./outputdir\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.04228664.

# %%
results = estimator.predict(eval_dataset)
 
Yout_ = [result["Yout"] for result in results]
 
actual = Y_test[:, -1]

fig, ax = plt.subplots(figsize=(20,8))
 
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.plot(actual, label="Actual Values", color='green')
plt.plot(Yout_, label="Predicted Values", color='red', )
 
plt.show()
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./outputdir\model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
