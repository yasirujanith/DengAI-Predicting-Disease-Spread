# %%
import pandas as pd
import numpy as np

# %matplotlib inline
from matplotlib import pyplot as plt
plt.figure(figsize=(10,10))

import xgboost as xgb
from sklearn.metrics import mean_squared_error

from sklearn.model_selection import train_test_split

# %%
# def preprocess_data(data_path, labels_path=None):
    
#     x_features = ['reanalysis_specific_humidity_g_per_kg', 
#                  'reanalysis_dew_point_temp_k', 
#                  'station_avg_temp_c', 
#                  'station_min_temp_c']
#     y_features = ['total_cases']
    
    
#     x_df = pd.read_csv(data_path)
#     x_df.fillna(method='ffill', inplace=True)
#     sj_x = x_df[x_df['city']=='sj'][x_features]
#     iq_x = x_df[x_df['city']=='iq'][x_features]
    

#     # labels
#     sj_y = None
#     iq_y = None
#     if labels_path:
#         y_df = pd.read_csv(labels_path)
#         sj_y = y_df[y_df['city']=='sj'][y_features]
#         iq_y = y_df[y_df['city']=='iq'][y_features]

#     return sj_x, iq_x, sj_y, iq_y

# %%
# def preprocess_data_test(data_path, labels_path=None):
    
#     x_features = ['reanalysis_specific_humidity_g_per_kg', 
#                  'reanalysis_dew_point_temp_k', 
#                  'station_avg_temp_c', 
#                  'station_min_temp_c']
#     y_features = ['total_cases']
    
    
#     df = pd.read_csv(data_path)


#     # labels
#     if labels_path:
#         labels = pd.read_csv(labels_path)
#         df = df.join(labels)
        
#     #remove rows with any null values
#     df.dropna(inplace=True)
                
#     sj_x = df[df['city']=='sj'][x_features]
#     iq_x = df[df['city']=='iq'][x_features]

#     sj_y = df[df['city']=='sj'][y_features]
#     iq_y = df[df['city']=='iq'][y_features]


#     return sj_x, iq_x, sj_y, iq_y

# %%
def preprocess_data(data_path, labels_path=None):
    # load data and set index to city, year, weekofyear
    df = pd.read_csv(data_path, index_col=[0, 1, 2])
    
    # select features we want
    features = ['reanalysis_specific_humidity_g_per_kg', 
                 'reanalysis_dew_point_temp_k', 
                 'station_avg_temp_c', 
                 'station_min_temp_c']
    labels = ['total_cases']
    
    df = df[features]
    
    # fill missing values
    # df.fillna(method='ffill', inplace=True)

    # add labels to dataframe
    if labels_path:
        labels_df = pd.read_csv(labels_path, index_col=[0, 1, 2])
        df = df.join(labels_df)
    
    #remove rows with any null values
    df.dropna(inplace=True)
        
    # separate san juan and iquitos
    sj = df.loc['sj']
    iq = df.loc['iq']
    
    sj_x = sj[features]
    iq_x = iq[features]
    
    sj_y = None
    iq_y = None
    if labels_path:
        sj_y = sj[labels]
        iq_y = iq[labels]

    
    return sj_x, iq_x, sj_y, iq_y

# %%
def preprocess_data_test(data_path, labels_path=None):
    # load data and set index to city, year, weekofyear
    df = pd.read_csv(data_path, index_col=[0, 1, 2])
    
    # select features we want
    features = ['reanalysis_specific_humidity_g_per_kg', 
                 'reanalysis_dew_point_temp_k', 
                 'station_avg_temp_c', 
                 'station_min_temp_c']
    labels = ['total_cases']
    
    df = df[features]
    
    # fill missing values
    df.fillna(method='ffill', inplace=True)

    # add labels to dataframe
    if labels_path:
        labels_df = pd.read_csv(labels_path, index_col=[0, 1, 2])
        df = df.join(labels_df)
    
    # remove rows with any null values
    #df.dropna(inplace=True)
        
    # separate san juan and iquitos
    sj = df.loc['sj']
    iq = df.loc['iq']
    
    sj_x = sj[features]
    iq_x = iq[features]
    
    sj_y = None
    iq_y = None
    if labels_path:
        sj_y = sj[labels]
        iq_y = iq[labels]

    
    return sj_x, iq_x, sj_y, iq_y

# %%
sj_x, iq_x, sj_y, iq_y = preprocess_data('./data-processed/dengue_features_train.csv', labels_path='./data-processed/dengue_labels_train.csv')

# %%
print('sj_x - ', sj_x.shape)
print('sj_y - ', sj_y.shape)
print('iq_x - ', iq_x.shape)
print('iq_y - ', iq_y.shape)
# Out:
# sj_x -  (930, 4)
# sj_y -  (930, 1)
# iq_x -  (483, 4)
# iq_y -  (483, 1)

# %%
learning_rates = [ 0.05, 0.01, 0.1, 0.2, 0.25]
colsample_bytree = [0.6, 0.7, 0.8, 0.9, 0.95]
n_estimators = [5, 10, 15, 30, 40, 45]
max_depth = [3, 4, 5, 9, 10, 11]

def hyper_param_optimize(X, Y):
    
    lr_best = learning_rates[0]
    cs_best = colsample_bytree[0]
    es_best = n_estimators[0]
    md_best = max_depth[0]
    
    best_mse = float("inf")
    counter = 0
    
    for lr in learning_rates:
        for cs in colsample_bytree:
            for es in n_estimators:
                for md in max_depth:
                    counter += 1
                    print('step', counter, 'lr', lr, 'cs', cs, 'es', es, 'md', md)
                    
                    x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.20)
                    
                    model = xgb.XGBRegressor(
                        objective ='reg:linear',
                        colsample_bytree = cs, learning_rate = lr, max_depth = md, n_estimators = es
                    )
                    model.fit(x_train, y_train)
                    y_predict = model.predict(x_test)
                    
                    mse = mean_squared_error(y_test, y_predict)**0.5
                    
                    if (mse < best_mse):
                        best_mse = mse
                        lr_best = lr
                        cs_best = cs
                        es_best = es
                        md_best = md
    print('** best model - lr', lr_best, 'cs', cs_best, 'es', es_best, 'md', md_best)
    print('** best MSE - ', best_mse)
    
    return {'learning_rate': lr_best, 'colsample_bytree': cs_best, 'max_depth': md_best, 'n_estimators': es_best}

# %%
sj_param = hyper_param_optimize(sj_x, sj_y)
# Out:
# step 1 lr 0.05 cs 0.6 es 5 md 3
# step 2 lr 0.05 cs 0.6 es 5 md 4
# step 3 lr 0.05 cs 0.6 es 5 md 5
# step 4 lr 0.05 cs 0.6 es 5 md 9
# step 5 lr 0.05 cs 0.6 es 5 md 10
# step 6 lr 0.05 cs 0.6 es 5 md 11
# step 7 lr 0.05 cs 0.6 es 10 md 3
# step 8 lr 0.05 cs 0.6 es 10 md 4
# step 9 lr 0.05 cs 0.6 es 10 md 5
# step 10 lr 0.05 cs 0.6 es 10 md 9
# step 11 lr 0.05 cs 0.6 es 10 md 10
# step 12 lr 0.05 cs 0.6 es 10 md 11
# step 13 lr 0.05 cs 0.6 es 15 md 3
# step 14 lr 0.05 cs 0.6 es 15 md 4
# step 15 lr 0.05 cs 0.6 es 15 md 5
# step 16 lr 0.05 cs 0.6 es 15 md 9
# step 17 lr 0.05 cs 0.6 es 15 md 10
# step 18 lr 0.05 cs 0.6 es 15 md 11
# step 19 lr 0.05 cs 0.6 es 30 md 3
# step 20 lr 0.05 cs 0.6 es 30 md 4
# step 21 lr 0.05 cs 0.6 es 30 md 5
# step 22 lr 0.05 cs 0.6 es 30 md 9
# step 23 lr 0.05 cs 0.6 es 30 md 10
# step 24 lr 0.05 cs 0.6 es 30 md 11
# step 25 lr 0.05 cs 0.6 es 40 md 3
# step 26 lr 0.05 cs 0.6 es 40 md 4
# step 27 lr 0.05 cs 0.6 es 40 md 5
# step 28 lr 0.05 cs 0.6 es 40 md 9
# step 29 lr 0.05 cs 0.6 es 40 md 10
# step 30 lr 0.05 cs 0.6 es 40 md 11
# step 31 lr 0.05 cs 0.6 es 45 md 3
# step 32 lr 0.05 cs 0.6 es 45 md 4
# step 33 lr 0.05 cs 0.6 es 45 md 5
# step 34 lr 0.05 cs 0.6 es 45 md 9
# step 35 lr 0.05 cs 0.6 es 45 md 10
# step 36 lr 0.05 cs 0.6 es 45 md 11
# step 37 lr 0.05 cs 0.7 es 5 md 3
# step 38 lr 0.05 cs 0.7 es 5 md 4
# step 39 lr 0.05 cs 0.7 es 5 md 5
# step 40 lr 0.05 cs 0.7 es 5 md 9
# step 41 lr 0.05 cs 0.7 es 5 md 10
# step 42 lr 0.05 cs 0.7 es 5 md 11
# step 43 lr 0.05 cs 0.7 es 10 md 3
# step 44 lr 0.05 cs 0.7 es 10 md 4
# step 45 lr 0.05 cs 0.7 es 10 md 5
# step 46 lr 0.05 cs 0.7 es 10 md 9
# step 47 lr 0.05 cs 0.7 es 10 md 10
# step 48 lr 0.05 cs 0.7 es 10 md 11
# step 49 lr 0.05 cs 0.7 es 15 md 3
# step 50 lr 0.05 cs 0.7 es 15 md 4
# step 51 lr 0.05 cs 0.7 es 15 md 5
# step 52 lr 0.05 cs 0.7 es 15 md 9
# step 53 lr 0.05 cs 0.7 es 15 md 10
# step 54 lr 0.05 cs 0.7 es 15 md 11
# step 55 lr 0.05 cs 0.7 es 30 md 3
# step 56 lr 0.05 cs 0.7 es 30 md 4
# step 57 lr 0.05 cs 0.7 es 30 md 5
# step 58 lr 0.05 cs 0.7 es 30 md 9
# step 59 lr 0.05 cs 0.7 es 30 md 10
# step 60 lr 0.05 cs 0.7 es 30 md 11
# step 61 lr 0.05 cs 0.7 es 40 md 3
# step 62 lr 0.05 cs 0.7 es 40 md 4
# step 63 lr 0.05 cs 0.7 es 40 md 5
# step 64 lr 0.05 cs 0.7 es 40 md 9
# step 65 lr 0.05 cs 0.7 es 40 md 10
# step 66 lr 0.05 cs 0.7 es 40 md 11
# step 67 lr 0.05 cs 0.7 es 45 md 3
# step 68 lr 0.05 cs 0.7 es 45 md 4
# step 69 lr 0.05 cs 0.7 es 45 md 5
# step 70 lr 0.05 cs 0.7 es 45 md 9
# step 71 lr 0.05 cs 0.7 es 45 md 10
# step 72 lr 0.05 cs 0.7 es 45 md 11
# step 73 lr 0.05 cs 0.8 es 5 md 3
# step 74 lr 0.05 cs 0.8 es 5 md 4
# step 75 lr 0.05 cs 0.8 es 5 md 5
# step 76 lr 0.05 cs 0.8 es 5 md 9
# step 77 lr 0.05 cs 0.8 es 5 md 10
# step 78 lr 0.05 cs 0.8 es 5 md 11
# step 79 lr 0.05 cs 0.8 es 10 md 3
# step 80 lr 0.05 cs 0.8 es 10 md 4
# step 81 lr 0.05 cs 0.8 es 10 md 5
# step 82 lr 0.05 cs 0.8 es 10 md 9
# step 83 lr 0.05 cs 0.8 es 10 md 10
# step 84 lr 0.05 cs 0.8 es 10 md 11
# step 85 lr 0.05 cs 0.8 es 15 md 3
# step 86 lr 0.05 cs 0.8 es 15 md 4
# step 87 lr 0.05 cs 0.8 es 15 md 5
# step 88 lr 0.05 cs 0.8 es 15 md 9
# step 89 lr 0.05 cs 0.8 es 15 md 10
# step 90 lr 0.05 cs 0.8 es 15 md 11
# step 91 lr 0.05 cs 0.8 es 30 md 3
# step 92 lr 0.05 cs 0.8 es 30 md 4
# step 93 lr 0.05 cs 0.8 es 30 md 5
# step 94 lr 0.05 cs 0.8 es 30 md 9
# step 95 lr 0.05 cs 0.8 es 30 md 10
# step 96 lr 0.05 cs 0.8 es 30 md 11
# step 97 lr 0.05 cs 0.8 es 40 md 3
# step 98 lr 0.05 cs 0.8 es 40 md 4
# step 99 lr 0.05 cs 0.8 es 40 md 5
# step 100 lr 0.05 cs 0.8 es 40 md 9
# step 101 lr 0.05 cs 0.8 es 40 md 10
# step 102 lr 0.05 cs 0.8 es 40 md 11
# step 103 lr 0.05 cs 0.8 es 45 md 3
# step 104 lr 0.05 cs 0.8 es 45 md 4
# step 105 lr 0.05 cs 0.8 es 45 md 5
# step 106 lr 0.05 cs 0.8 es 45 md 9
# step 107 lr 0.05 cs 0.8 es 45 md 10
# step 108 lr 0.05 cs 0.8 es 45 md 11
# step 109 lr 0.05 cs 0.9 es 5 md 3
# step 110 lr 0.05 cs 0.9 es 5 md 4
# step 111 lr 0.05 cs 0.9 es 5 md 5
# step 112 lr 0.05 cs 0.9 es 5 md 9
# step 113 lr 0.05 cs 0.9 es 5 md 10
# step 114 lr 0.05 cs 0.9 es 5 md 11
# step 115 lr 0.05 cs 0.9 es 10 md 3
# step 116 lr 0.05 cs 0.9 es 10 md 4
# step 117 lr 0.05 cs 0.9 es 10 md 5
# step 118 lr 0.05 cs 0.9 es 10 md 9
# step 119 lr 0.05 cs 0.9 es 10 md 10
# step 120 lr 0.05 cs 0.9 es 10 md 11
# step 121 lr 0.05 cs 0.9 es 15 md 3
# step 122 lr 0.05 cs 0.9 es 15 md 4
# step 123 lr 0.05 cs 0.9 es 15 md 5
# step 124 lr 0.05 cs 0.9 es 15 md 9
# step 125 lr 0.05 cs 0.9 es 15 md 10
# step 126 lr 0.05 cs 0.9 es 15 md 11
# step 127 lr 0.05 cs 0.9 es 30 md 3
# step 128 lr 0.05 cs 0.9 es 30 md 4
# step 129 lr 0.05 cs 0.9 es 30 md 5
# step 130 lr 0.05 cs 0.9 es 30 md 9
# step 131 lr 0.05 cs 0.9 es 30 md 10
# step 132 lr 0.05 cs 0.9 es 30 md 11
# step 133 lr 0.05 cs 0.9 es 40 md 3
# step 134 lr 0.05 cs 0.9 es 40 md 4
# step 135 lr 0.05 cs 0.9 es 40 md 5
# step 136 lr 0.05 cs 0.9 es 40 md 9
# step 137 lr 0.05 cs 0.9 es 40 md 10
# step 138 lr 0.05 cs 0.9 es 40 md 11
# step 139 lr 0.05 cs 0.9 es 45 md 3
# step 140 lr 0.05 cs 0.9 es 45 md 4
# step 141 lr 0.05 cs 0.9 es 45 md 5
# step 142 lr 0.05 cs 0.9 es 45 md 9
# step 143 lr 0.05 cs 0.9 es 45 md 10
# step 144 lr 0.05 cs 0.9 es 45 md 11
# step 145 lr 0.05 cs 0.95 es 5 md 3
# step 146 lr 0.05 cs 0.95 es 5 md 4
# step 147 lr 0.05 cs 0.95 es 5 md 5
# step 148 lr 0.05 cs 0.95 es 5 md 9
# step 149 lr 0.05 cs 0.95 es 5 md 10
# step 150 lr 0.05 cs 0.95 es 5 md 11
# step 151 lr 0.05 cs 0.95 es 10 md 3
# step 152 lr 0.05 cs 0.95 es 10 md 4
# step 153 lr 0.05 cs 0.95 es 10 md 5
# step 154 lr 0.05 cs 0.95 es 10 md 9
# step 155 lr 0.05 cs 0.95 es 10 md 10
# step 156 lr 0.05 cs 0.95 es 10 md 11
# step 157 lr 0.05 cs 0.95 es 15 md 3
# step 158 lr 0.05 cs 0.95 es 15 md 4
# step 159 lr 0.05 cs 0.95 es 15 md 5
# step 160 lr 0.05 cs 0.95 es 15 md 9
# step 161 lr 0.05 cs 0.95 es 15 md 10
# step 162 lr 0.05 cs 0.95 es 15 md 11
# step 163 lr 0.05 cs 0.95 es 30 md 3
# step 164 lr 0.05 cs 0.95 es 30 md 4
# step 165 lr 0.05 cs 0.95 es 30 md 5
# step 166 lr 0.05 cs 0.95 es 30 md 9
# step 167 lr 0.05 cs 0.95 es 30 md 10
# step 168 lr 0.05 cs 0.95 es 30 md 11
# step 169 lr 0.05 cs 0.95 es 40 md 3
# step 170 lr 0.05 cs 0.95 es 40 md 4
# step 171 lr 0.05 cs 0.95 es 40 md 5
# step 172 lr 0.05 cs 0.95 es 40 md 9
# step 173 lr 0.05 cs 0.95 es 40 md 10
# step 174 lr 0.05 cs 0.95 es 40 md 11
# step 175 lr 0.05 cs 0.95 es 45 md 3
# step 176 lr 0.05 cs 0.95 es 45 md 4
# step 177 lr 0.05 cs 0.95 es 45 md 5
# step 178 lr 0.05 cs 0.95 es 45 md 9
# step 179 lr 0.05 cs 0.95 es 45 md 10
# step 180 lr 0.05 cs 0.95 es 45 md 11
# step 181 lr 0.01 cs 0.6 es 5 md 3
# step 182 lr 0.01 cs 0.6 es 5 md 4
# step 183 lr 0.01 cs 0.6 es 5 md 5
# step 184 lr 0.01 cs 0.6 es 5 md 9
# step 185 lr 0.01 cs 0.6 es 5 md 10
# step 186 lr 0.01 cs 0.6 es 5 md 11
# step 187 lr 0.01 cs 0.6 es 10 md 3
# step 188 lr 0.01 cs 0.6 es 10 md 4
# step 189 lr 0.01 cs 0.6 es 10 md 5
# step 190 lr 0.01 cs 0.6 es 10 md 9
# step 191 lr 0.01 cs 0.6 es 10 md 10
# step 192 lr 0.01 cs 0.6 es 10 md 11
# step 193 lr 0.01 cs 0.6 es 15 md 3
# step 194 lr 0.01 cs 0.6 es 15 md 4
# step 195 lr 0.01 cs 0.6 es 15 md 5
# step 196 lr 0.01 cs 0.6 es 15 md 9
# step 197 lr 0.01 cs 0.6 es 15 md 10
# step 198 lr 0.01 cs 0.6 es 15 md 11
# step 199 lr 0.01 cs 0.6 es 30 md 3
# step 200 lr 0.01 cs 0.6 es 30 md 4
# step 201 lr 0.01 cs 0.6 es 30 md 5
# step 202 lr 0.01 cs 0.6 es 30 md 9
# step 203 lr 0.01 cs 0.6 es 30 md 10
# step 204 lr 0.01 cs 0.6 es 30 md 11
# step 205 lr 0.01 cs 0.6 es 40 md 3
# step 206 lr 0.01 cs 0.6 es 40 md 4
# step 207 lr 0.01 cs 0.6 es 40 md 5
# step 208 lr 0.01 cs 0.6 es 40 md 9
# step 209 lr 0.01 cs 0.6 es 40 md 10
# step 210 lr 0.01 cs 0.6 es 40 md 11
# step 211 lr 0.01 cs 0.6 es 45 md 3
# step 212 lr 0.01 cs 0.6 es 45 md 4
# step 213 lr 0.01 cs 0.6 es 45 md 5
# step 214 lr 0.01 cs 0.6 es 45 md 9
# step 215 lr 0.01 cs 0.6 es 45 md 10
# step 216 lr 0.01 cs 0.6 es 45 md 11
# step 217 lr 0.01 cs 0.7 es 5 md 3
# step 218 lr 0.01 cs 0.7 es 5 md 4
# step 219 lr 0.01 cs 0.7 es 5 md 5
# step 220 lr 0.01 cs 0.7 es 5 md 9
# step 221 lr 0.01 cs 0.7 es 5 md 10
# step 222 lr 0.01 cs 0.7 es 5 md 11
# step 223 lr 0.01 cs 0.7 es 10 md 3
# step 224 lr 0.01 cs 0.7 es 10 md 4
# step 225 lr 0.01 cs 0.7 es 10 md 5
# step 226 lr 0.01 cs 0.7 es 10 md 9
# step 227 lr 0.01 cs 0.7 es 10 md 10
# step 228 lr 0.01 cs 0.7 es 10 md 11
# step 229 lr 0.01 cs 0.7 es 15 md 3
# step 230 lr 0.01 cs 0.7 es 15 md 4
# step 231 lr 0.01 cs 0.7 es 15 md 5
# step 232 lr 0.01 cs 0.7 es 15 md 9
# step 233 lr 0.01 cs 0.7 es 15 md 10
# step 234 lr 0.01 cs 0.7 es 15 md 11
# step 235 lr 0.01 cs 0.7 es 30 md 3
# step 236 lr 0.01 cs 0.7 es 30 md 4
# step 237 lr 0.01 cs 0.7 es 30 md 5
# step 238 lr 0.01 cs 0.7 es 30 md 9
# step 239 lr 0.01 cs 0.7 es 30 md 10
# step 240 lr 0.01 cs 0.7 es 30 md 11
# step 241 lr 0.01 cs 0.7 es 40 md 3
# step 242 lr 0.01 cs 0.7 es 40 md 4
# step 243 lr 0.01 cs 0.7 es 40 md 5
# step 244 lr 0.01 cs 0.7 es 40 md 9
# step 245 lr 0.01 cs 0.7 es 40 md 10
# step 246 lr 0.01 cs 0.7 es 40 md 11
# step 247 lr 0.01 cs 0.7 es 45 md 3
# step 248 lr 0.01 cs 0.7 es 45 md 4
# step 249 lr 0.01 cs 0.7 es 45 md 5
# step 250 lr 0.01 cs 0.7 es 45 md 9
# step 251 lr 0.01 cs 0.7 es 45 md 10
# step 252 lr 0.01 cs 0.7 es 45 md 11
# step 253 lr 0.01 cs 0.8 es 5 md 3
# step 254 lr 0.01 cs 0.8 es 5 md 4
# step 255 lr 0.01 cs 0.8 es 5 md 5
# step 256 lr 0.01 cs 0.8 es 5 md 9
# step 257 lr 0.01 cs 0.8 es 5 md 10
# step 258 lr 0.01 cs 0.8 es 5 md 11
# step 259 lr 0.01 cs 0.8 es 10 md 3
# step 260 lr 0.01 cs 0.8 es 10 md 4
# step 261 lr 0.01 cs 0.8 es 10 md 5
# step 262 lr 0.01 cs 0.8 es 10 md 9
# step 263 lr 0.01 cs 0.8 es 10 md 10
# step 264 lr 0.01 cs 0.8 es 10 md 11
# step 265 lr 0.01 cs 0.8 es 15 md 3
# step 266 lr 0.01 cs 0.8 es 15 md 4
# step 267 lr 0.01 cs 0.8 es 15 md 5
# step 268 lr 0.01 cs 0.8 es 15 md 9
# step 269 lr 0.01 cs 0.8 es 15 md 10
# step 270 lr 0.01 cs 0.8 es 15 md 11
# step 271 lr 0.01 cs 0.8 es 30 md 3
# step 272 lr 0.01 cs 0.8 es 30 md 4
# step 273 lr 0.01 cs 0.8 es 30 md 5
# step 274 lr 0.01 cs 0.8 es 30 md 9
# step 275 lr 0.01 cs 0.8 es 30 md 10
# step 276 lr 0.01 cs 0.8 es 30 md 11
# step 277 lr 0.01 cs 0.8 es 40 md 3
# step 278 lr 0.01 cs 0.8 es 40 md 4
# step 279 lr 0.01 cs 0.8 es 40 md 5
# step 280 lr 0.01 cs 0.8 es 40 md 9
# step 281 lr 0.01 cs 0.8 es 40 md 10
# step 282 lr 0.01 cs 0.8 es 40 md 11
# step 283 lr 0.01 cs 0.8 es 45 md 3
# step 284 lr 0.01 cs 0.8 es 45 md 4
# step 285 lr 0.01 cs 0.8 es 45 md 5
# step 286 lr 0.01 cs 0.8 es 45 md 9
# step 287 lr 0.01 cs 0.8 es 45 md 10
# step 288 lr 0.01 cs 0.8 es 45 md 11
# step 289 lr 0.01 cs 0.9 es 5 md 3
# step 290 lr 0.01 cs 0.9 es 5 md 4
# step 291 lr 0.01 cs 0.9 es 5 md 5
# step 292 lr 0.01 cs 0.9 es 5 md 9
# step 293 lr 0.01 cs 0.9 es 5 md 10
# step 294 lr 0.01 cs 0.9 es 5 md 11
# step 295 lr 0.01 cs 0.9 es 10 md 3
# step 296 lr 0.01 cs 0.9 es 10 md 4
# step 297 lr 0.01 cs 0.9 es 10 md 5
# step 298 lr 0.01 cs 0.9 es 10 md 9
# step 299 lr 0.01 cs 0.9 es 10 md 10
# step 300 lr 0.01 cs 0.9 es 10 md 11
# step 301 lr 0.01 cs 0.9 es 15 md 3
# step 302 lr 0.01 cs 0.9 es 15 md 4
# step 303 lr 0.01 cs 0.9 es 15 md 5
# step 304 lr 0.01 cs 0.9 es 15 md 9
# step 305 lr 0.01 cs 0.9 es 15 md 10
# step 306 lr 0.01 cs 0.9 es 15 md 11
# step 307 lr 0.01 cs 0.9 es 30 md 3
# step 308 lr 0.01 cs 0.9 es 30 md 4
# step 309 lr 0.01 cs 0.9 es 30 md 5
# step 310 lr 0.01 cs 0.9 es 30 md 9
# step 311 lr 0.01 cs 0.9 es 30 md 10
# step 312 lr 0.01 cs 0.9 es 30 md 11
# step 313 lr 0.01 cs 0.9 es 40 md 3
# step 314 lr 0.01 cs 0.9 es 40 md 4
# step 315 lr 0.01 cs 0.9 es 40 md 5
# step 316 lr 0.01 cs 0.9 es 40 md 9
# step 317 lr 0.01 cs 0.9 es 40 md 10
# step 318 lr 0.01 cs 0.9 es 40 md 11
# step 319 lr 0.01 cs 0.9 es 45 md 3
# step 320 lr 0.01 cs 0.9 es 45 md 4
# step 321 lr 0.01 cs 0.9 es 45 md 5
# step 322 lr 0.01 cs 0.9 es 45 md 9
# step 323 lr 0.01 cs 0.9 es 45 md 10
# step 324 lr 0.01 cs 0.9 es 45 md 11
# step 325 lr 0.01 cs 0.95 es 5 md 3
# step 326 lr 0.01 cs 0.95 es 5 md 4
# step 327 lr 0.01 cs 0.95 es 5 md 5
# step 328 lr 0.01 cs 0.95 es 5 md 9
# step 329 lr 0.01 cs 0.95 es 5 md 10
# step 330 lr 0.01 cs 0.95 es 5 md 11
# step 331 lr 0.01 cs 0.95 es 10 md 3
# step 332 lr 0.01 cs 0.95 es 10 md 4
# step 333 lr 0.01 cs 0.95 es 10 md 5
# step 334 lr 0.01 cs 0.95 es 10 md 9
# step 335 lr 0.01 cs 0.95 es 10 md 10
# step 336 lr 0.01 cs 0.95 es 10 md 11
# step 337 lr 0.01 cs 0.95 es 15 md 3
# step 338 lr 0.01 cs 0.95 es 15 md 4
# step 339 lr 0.01 cs 0.95 es 15 md 5
# step 340 lr 0.01 cs 0.95 es 15 md 9
# step 341 lr 0.01 cs 0.95 es 15 md 10
# step 342 lr 0.01 cs 0.95 es 15 md 11
# step 343 lr 0.01 cs 0.95 es 30 md 3
# step 344 lr 0.01 cs 0.95 es 30 md 4
# step 345 lr 0.01 cs 0.95 es 30 md 5
# step 346 lr 0.01 cs 0.95 es 30 md 9
# step 347 lr 0.01 cs 0.95 es 30 md 10
# step 348 lr 0.01 cs 0.95 es 30 md 11
# step 349 lr 0.01 cs 0.95 es 40 md 3
# step 350 lr 0.01 cs 0.95 es 40 md 4
# step 351 lr 0.01 cs 0.95 es 40 md 5
# step 352 lr 0.01 cs 0.95 es 40 md 9
# step 353 lr 0.01 cs 0.95 es 40 md 10
# step 354 lr 0.01 cs 0.95 es 40 md 11
# step 355 lr 0.01 cs 0.95 es 45 md 3
# step 356 lr 0.01 cs 0.95 es 45 md 4
# step 357 lr 0.01 cs 0.95 es 45 md 5
# step 358 lr 0.01 cs 0.95 es 45 md 9
# step 359 lr 0.01 cs 0.95 es 45 md 10
# step 360 lr 0.01 cs 0.95 es 45 md 11
# step 361 lr 0.1 cs 0.6 es 5 md 3
# step 362 lr 0.1 cs 0.6 es 5 md 4
# step 363 lr 0.1 cs 0.6 es 5 md 5
# step 364 lr 0.1 cs 0.6 es 5 md 9
# step 365 lr 0.1 cs 0.6 es 5 md 10
# step 366 lr 0.1 cs 0.6 es 5 md 11
# step 367 lr 0.1 cs 0.6 es 10 md 3
# step 368 lr 0.1 cs 0.6 es 10 md 4
# step 369 lr 0.1 cs 0.6 es 10 md 5
# step 370 lr 0.1 cs 0.6 es 10 md 9
# step 371 lr 0.1 cs 0.6 es 10 md 10
# step 372 lr 0.1 cs 0.6 es 10 md 11
# step 373 lr 0.1 cs 0.6 es 15 md 3
# step 374 lr 0.1 cs 0.6 es 15 md 4
# step 375 lr 0.1 cs 0.6 es 15 md 5
# step 376 lr 0.1 cs 0.6 es 15 md 9
# step 377 lr 0.1 cs 0.6 es 15 md 10
# step 378 lr 0.1 cs 0.6 es 15 md 11
# step 379 lr 0.1 cs 0.6 es 30 md 3
# step 380 lr 0.1 cs 0.6 es 30 md 4
# step 381 lr 0.1 cs 0.6 es 30 md 5
# step 382 lr 0.1 cs 0.6 es 30 md 9
# step 383 lr 0.1 cs 0.6 es 30 md 10
# step 384 lr 0.1 cs 0.6 es 30 md 11
# step 385 lr 0.1 cs 0.6 es 40 md 3
# step 386 lr 0.1 cs 0.6 es 40 md 4
# step 387 lr 0.1 cs 0.6 es 40 md 5
# step 388 lr 0.1 cs 0.6 es 40 md 9
# step 389 lr 0.1 cs 0.6 es 40 md 10
# step 390 lr 0.1 cs 0.6 es 40 md 11
# step 391 lr 0.1 cs 0.6 es 45 md 3
# step 392 lr 0.1 cs 0.6 es 45 md 4
# step 393 lr 0.1 cs 0.6 es 45 md 5
# step 394 lr 0.1 cs 0.6 es 45 md 9
# step 395 lr 0.1 cs 0.6 es 45 md 10
# step 396 lr 0.1 cs 0.6 es 45 md 11
# step 397 lr 0.1 cs 0.7 es 5 md 3
# step 398 lr 0.1 cs 0.7 es 5 md 4
# step 399 lr 0.1 cs 0.7 es 5 md 5
# step 400 lr 0.1 cs 0.7 es 5 md 9
# step 401 lr 0.1 cs 0.7 es 5 md 10
# step 402 lr 0.1 cs 0.7 es 5 md 11
# step 403 lr 0.1 cs 0.7 es 10 md 3
# step 404 lr 0.1 cs 0.7 es 10 md 4
# step 405 lr 0.1 cs 0.7 es 10 md 5
# step 406 lr 0.1 cs 0.7 es 10 md 9
# step 407 lr 0.1 cs 0.7 es 10 md 10
# step 408 lr 0.1 cs 0.7 es 10 md 11
# step 409 lr 0.1 cs 0.7 es 15 md 3
# step 410 lr 0.1 cs 0.7 es 15 md 4
# step 411 lr 0.1 cs 0.7 es 15 md 5
# step 412 lr 0.1 cs 0.7 es 15 md 9
# step 413 lr 0.1 cs 0.7 es 15 md 10
# step 414 lr 0.1 cs 0.7 es 15 md 11
# step 415 lr 0.1 cs 0.7 es 30 md 3
# step 416 lr 0.1 cs 0.7 es 30 md 4
# step 417 lr 0.1 cs 0.7 es 30 md 5
# step 418 lr 0.1 cs 0.7 es 30 md 9
# step 419 lr 0.1 cs 0.7 es 30 md 10
# step 420 lr 0.1 cs 0.7 es 30 md 11
# step 421 lr 0.1 cs 0.7 es 40 md 3
# step 422 lr 0.1 cs 0.7 es 40 md 4
# step 423 lr 0.1 cs 0.7 es 40 md 5
# step 424 lr 0.1 cs 0.7 es 40 md 9
# step 425 lr 0.1 cs 0.7 es 40 md 10
# step 426 lr 0.1 cs 0.7 es 40 md 11
# step 427 lr 0.1 cs 0.7 es 45 md 3
# step 428 lr 0.1 cs 0.7 es 45 md 4
# step 429 lr 0.1 cs 0.7 es 45 md 5
# step 430 lr 0.1 cs 0.7 es 45 md 9
# step 431 lr 0.1 cs 0.7 es 45 md 10
# step 432 lr 0.1 cs 0.7 es 45 md 11
# step 433 lr 0.1 cs 0.8 es 5 md 3
# step 434 lr 0.1 cs 0.8 es 5 md 4
# step 435 lr 0.1 cs 0.8 es 5 md 5
# step 436 lr 0.1 cs 0.8 es 5 md 9
# step 437 lr 0.1 cs 0.8 es 5 md 10
# step 438 lr 0.1 cs 0.8 es 5 md 11
# step 439 lr 0.1 cs 0.8 es 10 md 3
# step 440 lr 0.1 cs 0.8 es 10 md 4
# step 441 lr 0.1 cs 0.8 es 10 md 5
# step 442 lr 0.1 cs 0.8 es 10 md 9
# step 443 lr 0.1 cs 0.8 es 10 md 10
# step 444 lr 0.1 cs 0.8 es 10 md 11
# step 445 lr 0.1 cs 0.8 es 15 md 3
# step 446 lr 0.1 cs 0.8 es 15 md 4
# step 447 lr 0.1 cs 0.8 es 15 md 5
# step 448 lr 0.1 cs 0.8 es 15 md 9
# step 449 lr 0.1 cs 0.8 es 15 md 10
# step 450 lr 0.1 cs 0.8 es 15 md 11
# step 451 lr 0.1 cs 0.8 es 30 md 3
# step 452 lr 0.1 cs 0.8 es 30 md 4
# step 453 lr 0.1 cs 0.8 es 30 md 5
# step 454 lr 0.1 cs 0.8 es 30 md 9
# step 455 lr 0.1 cs 0.8 es 30 md 10
# step 456 lr 0.1 cs 0.8 es 30 md 11
# step 457 lr 0.1 cs 0.8 es 40 md 3
# step 458 lr 0.1 cs 0.8 es 40 md 4
# step 459 lr 0.1 cs 0.8 es 40 md 5
# step 460 lr 0.1 cs 0.8 es 40 md 9
# step 461 lr 0.1 cs 0.8 es 40 md 10
# step 462 lr 0.1 cs 0.8 es 40 md 11
# step 463 lr 0.1 cs 0.8 es 45 md 3
# step 464 lr 0.1 cs 0.8 es 45 md 4
# step 465 lr 0.1 cs 0.8 es 45 md 5
# step 466 lr 0.1 cs 0.8 es 45 md 9
# step 467 lr 0.1 cs 0.8 es 45 md 10
# step 468 lr 0.1 cs 0.8 es 45 md 11
# step 469 lr 0.1 cs 0.9 es 5 md 3
# step 470 lr 0.1 cs 0.9 es 5 md 4
# step 471 lr 0.1 cs 0.9 es 5 md 5
# step 472 lr 0.1 cs 0.9 es 5 md 9
# step 473 lr 0.1 cs 0.9 es 5 md 10
# step 474 lr 0.1 cs 0.9 es 5 md 11
# step 475 lr 0.1 cs 0.9 es 10 md 3
# step 476 lr 0.1 cs 0.9 es 10 md 4
# step 477 lr 0.1 cs 0.9 es 10 md 5
# step 478 lr 0.1 cs 0.9 es 10 md 9
# step 479 lr 0.1 cs 0.9 es 10 md 10
# step 480 lr 0.1 cs 0.9 es 10 md 11
# step 481 lr 0.1 cs 0.9 es 15 md 3
# step 482 lr 0.1 cs 0.9 es 15 md 4
# step 483 lr 0.1 cs 0.9 es 15 md 5
# step 484 lr 0.1 cs 0.9 es 15 md 9
# step 485 lr 0.1 cs 0.9 es 15 md 10
# step 486 lr 0.1 cs 0.9 es 15 md 11
# step 487 lr 0.1 cs 0.9 es 30 md 3
# step 488 lr 0.1 cs 0.9 es 30 md 4
# step 489 lr 0.1 cs 0.9 es 30 md 5
# step 490 lr 0.1 cs 0.9 es 30 md 9
# step 491 lr 0.1 cs 0.9 es 30 md 10
# step 492 lr 0.1 cs 0.9 es 30 md 11
# step 493 lr 0.1 cs 0.9 es 40 md 3
# step 494 lr 0.1 cs 0.9 es 40 md 4
# step 495 lr 0.1 cs 0.9 es 40 md 5
# step 496 lr 0.1 cs 0.9 es 40 md 9
# step 497 lr 0.1 cs 0.9 es 40 md 10
# step 498 lr 0.1 cs 0.9 es 40 md 11
# step 499 lr 0.1 cs 0.9 es 45 md 3
# step 500 lr 0.1 cs 0.9 es 45 md 4
# step 501 lr 0.1 cs 0.9 es 45 md 5
# step 502 lr 0.1 cs 0.9 es 45 md 9
# step 503 lr 0.1 cs 0.9 es 45 md 10
# step 504 lr 0.1 cs 0.9 es 45 md 11
# step 505 lr 0.1 cs 0.95 es 5 md 3
# step 506 lr 0.1 cs 0.95 es 5 md 4
# step 507 lr 0.1 cs 0.95 es 5 md 5
# step 508 lr 0.1 cs 0.95 es 5 md 9
# step 509 lr 0.1 cs 0.95 es 5 md 10
# step 510 lr 0.1 cs 0.95 es 5 md 11
# step 511 lr 0.1 cs 0.95 es 10 md 3
# step 512 lr 0.1 cs 0.95 es 10 md 4
# step 513 lr 0.1 cs 0.95 es 10 md 5
# step 514 lr 0.1 cs 0.95 es 10 md 9
# step 515 lr 0.1 cs 0.95 es 10 md 10
# step 516 lr 0.1 cs 0.95 es 10 md 11
# step 517 lr 0.1 cs 0.95 es 15 md 3
# step 518 lr 0.1 cs 0.95 es 15 md 4
# step 519 lr 0.1 cs 0.95 es 15 md 5
# step 520 lr 0.1 cs 0.95 es 15 md 9
# step 521 lr 0.1 cs 0.95 es 15 md 10
# step 522 lr 0.1 cs 0.95 es 15 md 11
# step 523 lr 0.1 cs 0.95 es 30 md 3
# step 524 lr 0.1 cs 0.95 es 30 md 4
# step 525 lr 0.1 cs 0.95 es 30 md 5
# step 526 lr 0.1 cs 0.95 es 30 md 9
# step 527 lr 0.1 cs 0.95 es 30 md 10
# step 528 lr 0.1 cs 0.95 es 30 md 11
# step 529 lr 0.1 cs 0.95 es 40 md 3
# step 530 lr 0.1 cs 0.95 es 40 md 4
# step 531 lr 0.1 cs 0.95 es 40 md 5
# step 532 lr 0.1 cs 0.95 es 40 md 9
# step 533 lr 0.1 cs 0.95 es 40 md 10
# step 534 lr 0.1 cs 0.95 es 40 md 11
# step 535 lr 0.1 cs 0.95 es 45 md 3
# step 536 lr 0.1 cs 0.95 es 45 md 4
# step 537 lr 0.1 cs 0.95 es 45 md 5
# step 538 lr 0.1 cs 0.95 es 45 md 9
# step 539 lr 0.1 cs 0.95 es 45 md 10
# step 540 lr 0.1 cs 0.95 es 45 md 11
# step 541 lr 0.2 cs 0.6 es 5 md 3
# step 542 lr 0.2 cs 0.6 es 5 md 4
# step 543 lr 0.2 cs 0.6 es 5 md 5
# step 544 lr 0.2 cs 0.6 es 5 md 9
# step 545 lr 0.2 cs 0.6 es 5 md 10
# step 546 lr 0.2 cs 0.6 es 5 md 11
# step 547 lr 0.2 cs 0.6 es 10 md 3
# step 548 lr 0.2 cs 0.6 es 10 md 4
# step 549 lr 0.2 cs 0.6 es 10 md 5
# step 550 lr 0.2 cs 0.6 es 10 md 9
# step 551 lr 0.2 cs 0.6 es 10 md 10
# step 552 lr 0.2 cs 0.6 es 10 md 11
# step 553 lr 0.2 cs 0.6 es 15 md 3
# step 554 lr 0.2 cs 0.6 es 15 md 4
# step 555 lr 0.2 cs 0.6 es 15 md 5
# step 556 lr 0.2 cs 0.6 es 15 md 9
# step 557 lr 0.2 cs 0.6 es 15 md 10
# step 558 lr 0.2 cs 0.6 es 15 md 11
# step 559 lr 0.2 cs 0.6 es 30 md 3
# step 560 lr 0.2 cs 0.6 es 30 md 4
# step 561 lr 0.2 cs 0.6 es 30 md 5
# step 562 lr 0.2 cs 0.6 es 30 md 9
# step 563 lr 0.2 cs 0.6 es 30 md 10
# step 564 lr 0.2 cs 0.6 es 30 md 11
# step 565 lr 0.2 cs 0.6 es 40 md 3
# step 566 lr 0.2 cs 0.6 es 40 md 4
# step 567 lr 0.2 cs 0.6 es 40 md 5
# step 568 lr 0.2 cs 0.6 es 40 md 9
# step 569 lr 0.2 cs 0.6 es 40 md 10
# step 570 lr 0.2 cs 0.6 es 40 md 11
# step 571 lr 0.2 cs 0.6 es 45 md 3
# step 572 lr 0.2 cs 0.6 es 45 md 4
# step 573 lr 0.2 cs 0.6 es 45 md 5
# step 574 lr 0.2 cs 0.6 es 45 md 9
# step 575 lr 0.2 cs 0.6 es 45 md 10
# step 576 lr 0.2 cs 0.6 es 45 md 11
# step 577 lr 0.2 cs 0.7 es 5 md 3
# step 578 lr 0.2 cs 0.7 es 5 md 4
# step 579 lr 0.2 cs 0.7 es 5 md 5
# step 580 lr 0.2 cs 0.7 es 5 md 9
# step 581 lr 0.2 cs 0.7 es 5 md 10
# step 582 lr 0.2 cs 0.7 es 5 md 11
# step 583 lr 0.2 cs 0.7 es 10 md 3
# step 584 lr 0.2 cs 0.7 es 10 md 4
# step 585 lr 0.2 cs 0.7 es 10 md 5
# step 586 lr 0.2 cs 0.7 es 10 md 9
# step 587 lr 0.2 cs 0.7 es 10 md 10
# step 588 lr 0.2 cs 0.7 es 10 md 11
# step 589 lr 0.2 cs 0.7 es 15 md 3
# step 590 lr 0.2 cs 0.7 es 15 md 4
# step 591 lr 0.2 cs 0.7 es 15 md 5
# step 592 lr 0.2 cs 0.7 es 15 md 9
# step 593 lr 0.2 cs 0.7 es 15 md 10
# step 594 lr 0.2 cs 0.7 es 15 md 11
# step 595 lr 0.2 cs 0.7 es 30 md 3
# step 596 lr 0.2 cs 0.7 es 30 md 4
# step 597 lr 0.2 cs 0.7 es 30 md 5
# step 598 lr 0.2 cs 0.7 es 30 md 9
# step 599 lr 0.2 cs 0.7 es 30 md 10
# step 600 lr 0.2 cs 0.7 es 30 md 11
# step 601 lr 0.2 cs 0.7 es 40 md 3
# step 602 lr 0.2 cs 0.7 es 40 md 4
# step 603 lr 0.2 cs 0.7 es 40 md 5
# step 604 lr 0.2 cs 0.7 es 40 md 9
# step 605 lr 0.2 cs 0.7 es 40 md 10
# step 606 lr 0.2 cs 0.7 es 40 md 11
# step 607 lr 0.2 cs 0.7 es 45 md 3
# step 608 lr 0.2 cs 0.7 es 45 md 4
# step 609 lr 0.2 cs 0.7 es 45 md 5
# step 610 lr 0.2 cs 0.7 es 45 md 9
# step 611 lr 0.2 cs 0.7 es 45 md 10
# step 612 lr 0.2 cs 0.7 es 45 md 11
# step 613 lr 0.2 cs 0.8 es 5 md 3
# step 614 lr 0.2 cs 0.8 es 5 md 4
# step 615 lr 0.2 cs 0.8 es 5 md 5
# step 616 lr 0.2 cs 0.8 es 5 md 9
# step 617 lr 0.2 cs 0.8 es 5 md 10
# step 618 lr 0.2 cs 0.8 es 5 md 11
# step 619 lr 0.2 cs 0.8 es 10 md 3
# step 620 lr 0.2 cs 0.8 es 10 md 4
# step 621 lr 0.2 cs 0.8 es 10 md 5
# step 622 lr 0.2 cs 0.8 es 10 md 9
# step 623 lr 0.2 cs 0.8 es 10 md 10
# step 624 lr 0.2 cs 0.8 es 10 md 11
# step 625 lr 0.2 cs 0.8 es 15 md 3
# step 626 lr 0.2 cs 0.8 es 15 md 4
# step 627 lr 0.2 cs 0.8 es 15 md 5
# step 628 lr 0.2 cs 0.8 es 15 md 9
# step 629 lr 0.2 cs 0.8 es 15 md 10
# step 630 lr 0.2 cs 0.8 es 15 md 11
# step 631 lr 0.2 cs 0.8 es 30 md 3
# step 632 lr 0.2 cs 0.8 es 30 md 4
# step 633 lr 0.2 cs 0.8 es 30 md 5
# step 634 lr 0.2 cs 0.8 es 30 md 9
# step 635 lr 0.2 cs 0.8 es 30 md 10
# step 636 lr 0.2 cs 0.8 es 30 md 11
# step 637 lr 0.2 cs 0.8 es 40 md 3
# step 638 lr 0.2 cs 0.8 es 40 md 4
# step 639 lr 0.2 cs 0.8 es 40 md 5
# step 640 lr 0.2 cs 0.8 es 40 md 9
# step 641 lr 0.2 cs 0.8 es 40 md 10
# step 642 lr 0.2 cs 0.8 es 40 md 11
# step 643 lr 0.2 cs 0.8 es 45 md 3
# step 644 lr 0.2 cs 0.8 es 45 md 4
# step 645 lr 0.2 cs 0.8 es 45 md 5
# step 646 lr 0.2 cs 0.8 es 45 md 9
# step 647 lr 0.2 cs 0.8 es 45 md 10
# step 648 lr 0.2 cs 0.8 es 45 md 11
# step 649 lr 0.2 cs 0.9 es 5 md 3
# step 650 lr 0.2 cs 0.9 es 5 md 4
# step 651 lr 0.2 cs 0.9 es 5 md 5
# step 652 lr 0.2 cs 0.9 es 5 md 9
# step 653 lr 0.2 cs 0.9 es 5 md 10
# step 654 lr 0.2 cs 0.9 es 5 md 11
# step 655 lr 0.2 cs 0.9 es 10 md 3
# step 656 lr 0.2 cs 0.9 es 10 md 4
# step 657 lr 0.2 cs 0.9 es 10 md 5
# step 658 lr 0.2 cs 0.9 es 10 md 9
# step 659 lr 0.2 cs 0.9 es 10 md 10
# step 660 lr 0.2 cs 0.9 es 10 md 11
# step 661 lr 0.2 cs 0.9 es 15 md 3
# step 662 lr 0.2 cs 0.9 es 15 md 4
# step 663 lr 0.2 cs 0.9 es 15 md 5
# step 664 lr 0.2 cs 0.9 es 15 md 9
# step 665 lr 0.2 cs 0.9 es 15 md 10
# step 666 lr 0.2 cs 0.9 es 15 md 11
# step 667 lr 0.2 cs 0.9 es 30 md 3
# step 668 lr 0.2 cs 0.9 es 30 md 4
# step 669 lr 0.2 cs 0.9 es 30 md 5
# step 670 lr 0.2 cs 0.9 es 30 md 9
# step 671 lr 0.2 cs 0.9 es 30 md 10
# step 672 lr 0.2 cs 0.9 es 30 md 11
# step 673 lr 0.2 cs 0.9 es 40 md 3
# step 674 lr 0.2 cs 0.9 es 40 md 4
# step 675 lr 0.2 cs 0.9 es 40 md 5
# step 676 lr 0.2 cs 0.9 es 40 md 9
# step 677 lr 0.2 cs 0.9 es 40 md 10
# step 678 lr 0.2 cs 0.9 es 40 md 11
# step 679 lr 0.2 cs 0.9 es 45 md 3
# step 680 lr 0.2 cs 0.9 es 45 md 4
# step 681 lr 0.2 cs 0.9 es 45 md 5
# step 682 lr 0.2 cs 0.9 es 45 md 9
# step 683 lr 0.2 cs 0.9 es 45 md 10
# step 684 lr 0.2 cs 0.9 es 45 md 11
# step 685 lr 0.2 cs 0.95 es 5 md 3
# step 686 lr 0.2 cs 0.95 es 5 md 4
# step 687 lr 0.2 cs 0.95 es 5 md 5
# step 688 lr 0.2 cs 0.95 es 5 md 9
# step 689 lr 0.2 cs 0.95 es 5 md 10
# step 690 lr 0.2 cs 0.95 es 5 md 11
# step 691 lr 0.2 cs 0.95 es 10 md 3
# step 692 lr 0.2 cs 0.95 es 10 md 4
# step 693 lr 0.2 cs 0.95 es 10 md 5
# step 694 lr 0.2 cs 0.95 es 10 md 9
# step 695 lr 0.2 cs 0.95 es 10 md 10
# step 696 lr 0.2 cs 0.95 es 10 md 11
# step 697 lr 0.2 cs 0.95 es 15 md 3
# step 698 lr 0.2 cs 0.95 es 15 md 4
# step 699 lr 0.2 cs 0.95 es 15 md 5
# step 700 lr 0.2 cs 0.95 es 15 md 9
# step 701 lr 0.2 cs 0.95 es 15 md 10
# step 702 lr 0.2 cs 0.95 es 15 md 11
# step 703 lr 0.2 cs 0.95 es 30 md 3
# step 704 lr 0.2 cs 0.95 es 30 md 4
# step 705 lr 0.2 cs 0.95 es 30 md 5
# step 706 lr 0.2 cs 0.95 es 30 md 9
# step 707 lr 0.2 cs 0.95 es 30 md 10
# step 708 lr 0.2 cs 0.95 es 30 md 11
# step 709 lr 0.2 cs 0.95 es 40 md 3
# step 710 lr 0.2 cs 0.95 es 40 md 4
# step 711 lr 0.2 cs 0.95 es 40 md 5
# step 712 lr 0.2 cs 0.95 es 40 md 9
# step 713 lr 0.2 cs 0.95 es 40 md 10
# step 714 lr 0.2 cs 0.95 es 40 md 11
# step 715 lr 0.2 cs 0.95 es 45 md 3
# step 716 lr 0.2 cs 0.95 es 45 md 4
# step 717 lr 0.2 cs 0.95 es 45 md 5
# step 718 lr 0.2 cs 0.95 es 45 md 9
# step 719 lr 0.2 cs 0.95 es 45 md 10
# step 720 lr 0.2 cs 0.95 es 45 md 11
# step 721 lr 0.25 cs 0.6 es 5 md 3
# step 722 lr 0.25 cs 0.6 es 5 md 4
# step 723 lr 0.25 cs 0.6 es 5 md 5
# step 724 lr 0.25 cs 0.6 es 5 md 9
# step 725 lr 0.25 cs 0.6 es 5 md 10
# step 726 lr 0.25 cs 0.6 es 5 md 11
# step 727 lr 0.25 cs 0.6 es 10 md 3
# step 728 lr 0.25 cs 0.6 es 10 md 4
# step 729 lr 0.25 cs 0.6 es 10 md 5
# step 730 lr 0.25 cs 0.6 es 10 md 9
# step 731 lr 0.25 cs 0.6 es 10 md 10
# step 732 lr 0.25 cs 0.6 es 10 md 11
# step 733 lr 0.25 cs 0.6 es 15 md 3
# step 734 lr 0.25 cs 0.6 es 15 md 4
# step 735 lr 0.25 cs 0.6 es 15 md 5
# step 736 lr 0.25 cs 0.6 es 15 md 9
# step 737 lr 0.25 cs 0.6 es 15 md 10
# step 738 lr 0.25 cs 0.6 es 15 md 11
# step 739 lr 0.25 cs 0.6 es 30 md 3
# step 740 lr 0.25 cs 0.6 es 30 md 4
# step 741 lr 0.25 cs 0.6 es 30 md 5
# step 742 lr 0.25 cs 0.6 es 30 md 9
# step 743 lr 0.25 cs 0.6 es 30 md 10
# step 744 lr 0.25 cs 0.6 es 30 md 11
# step 745 lr 0.25 cs 0.6 es 40 md 3
# step 746 lr 0.25 cs 0.6 es 40 md 4
# step 747 lr 0.25 cs 0.6 es 40 md 5
# step 748 lr 0.25 cs 0.6 es 40 md 9
# step 749 lr 0.25 cs 0.6 es 40 md 10
# step 750 lr 0.25 cs 0.6 es 40 md 11
# step 751 lr 0.25 cs 0.6 es 45 md 3
# step 752 lr 0.25 cs 0.6 es 45 md 4
# step 753 lr 0.25 cs 0.6 es 45 md 5
# step 754 lr 0.25 cs 0.6 es 45 md 9
# step 755 lr 0.25 cs 0.6 es 45 md 10
# step 756 lr 0.25 cs 0.6 es 45 md 11
# step 757 lr 0.25 cs 0.7 es 5 md 3
# step 758 lr 0.25 cs 0.7 es 5 md 4
# step 759 lr 0.25 cs 0.7 es 5 md 5
# step 760 lr 0.25 cs 0.7 es 5 md 9
# step 761 lr 0.25 cs 0.7 es 5 md 10
# step 762 lr 0.25 cs 0.7 es 5 md 11
# step 763 lr 0.25 cs 0.7 es 10 md 3
# step 764 lr 0.25 cs 0.7 es 10 md 4
# step 765 lr 0.25 cs 0.7 es 10 md 5
# step 766 lr 0.25 cs 0.7 es 10 md 9
# step 767 lr 0.25 cs 0.7 es 10 md 10
# step 768 lr 0.25 cs 0.7 es 10 md 11
# step 769 lr 0.25 cs 0.7 es 15 md 3
# step 770 lr 0.25 cs 0.7 es 15 md 4
# step 771 lr 0.25 cs 0.7 es 15 md 5
# step 772 lr 0.25 cs 0.7 es 15 md 9
# step 773 lr 0.25 cs 0.7 es 15 md 10
# step 774 lr 0.25 cs 0.7 es 15 md 11
# step 775 lr 0.25 cs 0.7 es 30 md 3
# step 776 lr 0.25 cs 0.7 es 30 md 4
# step 777 lr 0.25 cs 0.7 es 30 md 5
# step 778 lr 0.25 cs 0.7 es 30 md 9
# step 779 lr 0.25 cs 0.7 es 30 md 10
# step 780 lr 0.25 cs 0.7 es 30 md 11
# step 781 lr 0.25 cs 0.7 es 40 md 3
# step 782 lr 0.25 cs 0.7 es 40 md 4
# step 783 lr 0.25 cs 0.7 es 40 md 5
# step 784 lr 0.25 cs 0.7 es 40 md 9
# step 785 lr 0.25 cs 0.7 es 40 md 10
# step 786 lr 0.25 cs 0.7 es 40 md 11
# step 787 lr 0.25 cs 0.7 es 45 md 3
# step 788 lr 0.25 cs 0.7 es 45 md 4
# step 789 lr 0.25 cs 0.7 es 45 md 5
# step 790 lr 0.25 cs 0.7 es 45 md 9
# step 791 lr 0.25 cs 0.7 es 45 md 10
# step 792 lr 0.25 cs 0.7 es 45 md 11
# step 793 lr 0.25 cs 0.8 es 5 md 3
# step 794 lr 0.25 cs 0.8 es 5 md 4
# step 795 lr 0.25 cs 0.8 es 5 md 5
# step 796 lr 0.25 cs 0.8 es 5 md 9
# step 797 lr 0.25 cs 0.8 es 5 md 10
# step 798 lr 0.25 cs 0.8 es 5 md 11
# step 799 lr 0.25 cs 0.8 es 10 md 3
# step 800 lr 0.25 cs 0.8 es 10 md 4
# step 801 lr 0.25 cs 0.8 es 10 md 5
# step 802 lr 0.25 cs 0.8 es 10 md 9
# step 803 lr 0.25 cs 0.8 es 10 md 10
# step 804 lr 0.25 cs 0.8 es 10 md 11
# step 805 lr 0.25 cs 0.8 es 15 md 3
# step 806 lr 0.25 cs 0.8 es 15 md 4
# step 807 lr 0.25 cs 0.8 es 15 md 5
# step 808 lr 0.25 cs 0.8 es 15 md 9
# step 809 lr 0.25 cs 0.8 es 15 md 10
# step 810 lr 0.25 cs 0.8 es 15 md 11
# step 811 lr 0.25 cs 0.8 es 30 md 3
# step 812 lr 0.25 cs 0.8 es 30 md 4
# step 813 lr 0.25 cs 0.8 es 30 md 5
# step 814 lr 0.25 cs 0.8 es 30 md 9
# step 815 lr 0.25 cs 0.8 es 30 md 10
# step 816 lr 0.25 cs 0.8 es 30 md 11
# step 817 lr 0.25 cs 0.8 es 40 md 3
# step 818 lr 0.25 cs 0.8 es 40 md 4
# step 819 lr 0.25 cs 0.8 es 40 md 5
# step 820 lr 0.25 cs 0.8 es 40 md 9
# step 821 lr 0.25 cs 0.8 es 40 md 10
# step 822 lr 0.25 cs 0.8 es 40 md 11
# step 823 lr 0.25 cs 0.8 es 45 md 3
# step 824 lr 0.25 cs 0.8 es 45 md 4
# step 825 lr 0.25 cs 0.8 es 45 md 5
# step 826 lr 0.25 cs 0.8 es 45 md 9
# step 827 lr 0.25 cs 0.8 es 45 md 10
# step 828 lr 0.25 cs 0.8 es 45 md 11
# step 829 lr 0.25 cs 0.9 es 5 md 3
# step 830 lr 0.25 cs 0.9 es 5 md 4
# step 831 lr 0.25 cs 0.9 es 5 md 5
# step 832 lr 0.25 cs 0.9 es 5 md 9
# step 833 lr 0.25 cs 0.9 es 5 md 10
# step 834 lr 0.25 cs 0.9 es 5 md 11
# step 835 lr 0.25 cs 0.9 es 10 md 3
# step 836 lr 0.25 cs 0.9 es 10 md 4
# step 837 lr 0.25 cs 0.9 es 10 md 5
# step 838 lr 0.25 cs 0.9 es 10 md 9
# step 839 lr 0.25 cs 0.9 es 10 md 10
# step 840 lr 0.25 cs 0.9 es 10 md 11
# step 841 lr 0.25 cs 0.9 es 15 md 3
# step 842 lr 0.25 cs 0.9 es 15 md 4
# step 843 lr 0.25 cs 0.9 es 15 md 5
# step 844 lr 0.25 cs 0.9 es 15 md 9
# step 845 lr 0.25 cs 0.9 es 15 md 10
# step 846 lr 0.25 cs 0.9 es 15 md 11
# step 847 lr 0.25 cs 0.9 es 30 md 3
# step 848 lr 0.25 cs 0.9 es 30 md 4
# step 849 lr 0.25 cs 0.9 es 30 md 5
# step 850 lr 0.25 cs 0.9 es 30 md 9
# step 851 lr 0.25 cs 0.9 es 30 md 10
# step 852 lr 0.25 cs 0.9 es 30 md 11
# step 853 lr 0.25 cs 0.9 es 40 md 3
# step 854 lr 0.25 cs 0.9 es 40 md 4
# step 855 lr 0.25 cs 0.9 es 40 md 5
# step 856 lr 0.25 cs 0.9 es 40 md 9
# step 857 lr 0.25 cs 0.9 es 40 md 10
# step 858 lr 0.25 cs 0.9 es 40 md 11
# step 859 lr 0.25 cs 0.9 es 45 md 3
# step 860 lr 0.25 cs 0.9 es 45 md 4
# step 861 lr 0.25 cs 0.9 es 45 md 5
# step 862 lr 0.25 cs 0.9 es 45 md 9
# step 863 lr 0.25 cs 0.9 es 45 md 10
# step 864 lr 0.25 cs 0.9 es 45 md 11
# step 865 lr 0.25 cs 0.95 es 5 md 3
# step 866 lr 0.25 cs 0.95 es 5 md 4
# step 867 lr 0.25 cs 0.95 es 5 md 5
# step 868 lr 0.25 cs 0.95 es 5 md 9
# step 869 lr 0.25 cs 0.95 es 5 md 10
# step 870 lr 0.25 cs 0.95 es 5 md 11
# step 871 lr 0.25 cs 0.95 es 10 md 3
# step 872 lr 0.25 cs 0.95 es 10 md 4
# step 873 lr 0.25 cs 0.95 es 10 md 5
# step 874 lr 0.25 cs 0.95 es 10 md 9
# step 875 lr 0.25 cs 0.95 es 10 md 10
# step 876 lr 0.25 cs 0.95 es 10 md 11
# step 877 lr 0.25 cs 0.95 es 15 md 3
# step 878 lr 0.25 cs 0.95 es 15 md 4
# step 879 lr 0.25 cs 0.95 es 15 md 5
# step 880 lr 0.25 cs 0.95 es 15 md 9
# step 881 lr 0.25 cs 0.95 es 15 md 10
# step 882 lr 0.25 cs 0.95 es 15 md 11
# step 883 lr 0.25 cs 0.95 es 30 md 3
# step 884 lr 0.25 cs 0.95 es 30 md 4
# step 885 lr 0.25 cs 0.95 es 30 md 5
# step 886 lr 0.25 cs 0.95 es 30 md 9
# step 887 lr 0.25 cs 0.95 es 30 md 10
# step 888 lr 0.25 cs 0.95 es 30 md 11
# step 889 lr 0.25 cs 0.95 es 40 md 3
# step 890 lr 0.25 cs 0.95 es 40 md 4
# step 891 lr 0.25 cs 0.95 es 40 md 5
# step 892 lr 0.25 cs 0.95 es 40 md 9
# step 893 lr 0.25 cs 0.95 es 40 md 10
# step 894 lr 0.25 cs 0.95 es 40 md 11
# step 895 lr 0.25 cs 0.95 es 45 md 3
# step 896 lr 0.25 cs 0.95 es 45 md 4
# step 897 lr 0.25 cs 0.95 es 45 md 5
# step 898 lr 0.25 cs 0.95 es 45 md 9
# step 899 lr 0.25 cs 0.95 es 45 md 10
# step 900 lr 0.25 cs 0.95 es 45 md 11
# ** best model - lr 0.1 cs 0.6 es 15 md 9
# ** best MSE -  28.726898101479794

# %%
iq_param = hyper_param_optimize(iq_x, iq_y)
# Out:
# step 1 lr 0.05 cs 0.6 es 5 md 3
# step 2 lr 0.05 cs 0.6 es 5 md 4
# step 3 lr 0.05 cs 0.6 es 5 md 5
# step 4 lr 0.05 cs 0.6 es 5 md 9
# step 5 lr 0.05 cs 0.6 es 5 md 10
# step 6 lr 0.05 cs 0.6 es 5 md 11
# step 7 lr 0.05 cs 0.6 es 10 md 3
# step 8 lr 0.05 cs 0.6 es 10 md 4
# step 9 lr 0.05 cs 0.6 es 10 md 5
# step 10 lr 0.05 cs 0.6 es 10 md 9
# step 11 lr 0.05 cs 0.6 es 10 md 10
# step 12 lr 0.05 cs 0.6 es 10 md 11
# step 13 lr 0.05 cs 0.6 es 15 md 3
# step 14 lr 0.05 cs 0.6 es 15 md 4
# step 15 lr 0.05 cs 0.6 es 15 md 5
# step 16 lr 0.05 cs 0.6 es 15 md 9
# step 17 lr 0.05 cs 0.6 es 15 md 10
# step 18 lr 0.05 cs 0.6 es 15 md 11
# step 19 lr 0.05 cs 0.6 es 30 md 3
# step 20 lr 0.05 cs 0.6 es 30 md 4
# step 21 lr 0.05 cs 0.6 es 30 md 5
# step 22 lr 0.05 cs 0.6 es 30 md 9
# step 23 lr 0.05 cs 0.6 es 30 md 10
# step 24 lr 0.05 cs 0.6 es 30 md 11
# step 25 lr 0.05 cs 0.6 es 40 md 3
# step 26 lr 0.05 cs 0.6 es 40 md 4
# step 27 lr 0.05 cs 0.6 es 40 md 5
# step 28 lr 0.05 cs 0.6 es 40 md 9
# step 29 lr 0.05 cs 0.6 es 40 md 10
# step 30 lr 0.05 cs 0.6 es 40 md 11
# step 31 lr 0.05 cs 0.6 es 45 md 3
# step 32 lr 0.05 cs 0.6 es 45 md 4
# step 33 lr 0.05 cs 0.6 es 45 md 5
# step 34 lr 0.05 cs 0.6 es 45 md 9
# step 35 lr 0.05 cs 0.6 es 45 md 10
# step 36 lr 0.05 cs 0.6 es 45 md 11
# step 37 lr 0.05 cs 0.7 es 5 md 3
# step 38 lr 0.05 cs 0.7 es 5 md 4
# step 39 lr 0.05 cs 0.7 es 5 md 5
# step 40 lr 0.05 cs 0.7 es 5 md 9
# step 41 lr 0.05 cs 0.7 es 5 md 10
# step 42 lr 0.05 cs 0.7 es 5 md 11
# step 43 lr 0.05 cs 0.7 es 10 md 3
# step 44 lr 0.05 cs 0.7 es 10 md 4
# step 45 lr 0.05 cs 0.7 es 10 md 5
# step 46 lr 0.05 cs 0.7 es 10 md 9
# step 47 lr 0.05 cs 0.7 es 10 md 10
# step 48 lr 0.05 cs 0.7 es 10 md 11
# step 49 lr 0.05 cs 0.7 es 15 md 3
# step 50 lr 0.05 cs 0.7 es 15 md 4
# step 51 lr 0.05 cs 0.7 es 15 md 5
# step 52 lr 0.05 cs 0.7 es 15 md 9
# step 53 lr 0.05 cs 0.7 es 15 md 10
# step 54 lr 0.05 cs 0.7 es 15 md 11
# step 55 lr 0.05 cs 0.7 es 30 md 3
# step 56 lr 0.05 cs 0.7 es 30 md 4
# step 57 lr 0.05 cs 0.7 es 30 md 5
# step 58 lr 0.05 cs 0.7 es 30 md 9
# step 59 lr 0.05 cs 0.7 es 30 md 10
# step 60 lr 0.05 cs 0.7 es 30 md 11
# step 61 lr 0.05 cs 0.7 es 40 md 3
# step 62 lr 0.05 cs 0.7 es 40 md 4
# step 63 lr 0.05 cs 0.7 es 40 md 5
# step 64 lr 0.05 cs 0.7 es 40 md 9
# step 65 lr 0.05 cs 0.7 es 40 md 10
# step 66 lr 0.05 cs 0.7 es 40 md 11
# step 67 lr 0.05 cs 0.7 es 45 md 3
# step 68 lr 0.05 cs 0.7 es 45 md 4
# step 69 lr 0.05 cs 0.7 es 45 md 5
# step 70 lr 0.05 cs 0.7 es 45 md 9
# step 71 lr 0.05 cs 0.7 es 45 md 10
# step 72 lr 0.05 cs 0.7 es 45 md 11
# step 73 lr 0.05 cs 0.8 es 5 md 3
# step 74 lr 0.05 cs 0.8 es 5 md 4
# step 75 lr 0.05 cs 0.8 es 5 md 5
# step 76 lr 0.05 cs 0.8 es 5 md 9
# step 77 lr 0.05 cs 0.8 es 5 md 10
# step 78 lr 0.05 cs 0.8 es 5 md 11
# step 79 lr 0.05 cs 0.8 es 10 md 3
# step 80 lr 0.05 cs 0.8 es 10 md 4
# step 81 lr 0.05 cs 0.8 es 10 md 5
# step 82 lr 0.05 cs 0.8 es 10 md 9
# step 83 lr 0.05 cs 0.8 es 10 md 10
# step 84 lr 0.05 cs 0.8 es 10 md 11
# step 85 lr 0.05 cs 0.8 es 15 md 3
# step 86 lr 0.05 cs 0.8 es 15 md 4
# step 87 lr 0.05 cs 0.8 es 15 md 5
# step 88 lr 0.05 cs 0.8 es 15 md 9
# step 89 lr 0.05 cs 0.8 es 15 md 10
# step 90 lr 0.05 cs 0.8 es 15 md 11
# step 91 lr 0.05 cs 0.8 es 30 md 3
# step 92 lr 0.05 cs 0.8 es 30 md 4
# step 93 lr 0.05 cs 0.8 es 30 md 5
# step 94 lr 0.05 cs 0.8 es 30 md 9
# step 95 lr 0.05 cs 0.8 es 30 md 10
# step 96 lr 0.05 cs 0.8 es 30 md 11
# step 97 lr 0.05 cs 0.8 es 40 md 3
# step 98 lr 0.05 cs 0.8 es 40 md 4
# step 99 lr 0.05 cs 0.8 es 40 md 5
# step 100 lr 0.05 cs 0.8 es 40 md 9
# step 101 lr 0.05 cs 0.8 es 40 md 10
# step 102 lr 0.05 cs 0.8 es 40 md 11
# step 103 lr 0.05 cs 0.8 es 45 md 3
# step 104 lr 0.05 cs 0.8 es 45 md 4
# step 105 lr 0.05 cs 0.8 es 45 md 5
# step 106 lr 0.05 cs 0.8 es 45 md 9
# step 107 lr 0.05 cs 0.8 es 45 md 10
# step 108 lr 0.05 cs 0.8 es 45 md 11
# step 109 lr 0.05 cs 0.9 es 5 md 3
# step 110 lr 0.05 cs 0.9 es 5 md 4
# step 111 lr 0.05 cs 0.9 es 5 md 5
# step 112 lr 0.05 cs 0.9 es 5 md 9
# step 113 lr 0.05 cs 0.9 es 5 md 10
# step 114 lr 0.05 cs 0.9 es 5 md 11
# step 115 lr 0.05 cs 0.9 es 10 md 3
# step 116 lr 0.05 cs 0.9 es 10 md 4
# step 117 lr 0.05 cs 0.9 es 10 md 5
# step 118 lr 0.05 cs 0.9 es 10 md 9
# step 119 lr 0.05 cs 0.9 es 10 md 10
# step 120 lr 0.05 cs 0.9 es 10 md 11
# step 121 lr 0.05 cs 0.9 es 15 md 3
# step 122 lr 0.05 cs 0.9 es 15 md 4
# step 123 lr 0.05 cs 0.9 es 15 md 5
# step 124 lr 0.05 cs 0.9 es 15 md 9
# step 125 lr 0.05 cs 0.9 es 15 md 10
# step 126 lr 0.05 cs 0.9 es 15 md 11
# step 127 lr 0.05 cs 0.9 es 30 md 3
# step 128 lr 0.05 cs 0.9 es 30 md 4
# step 129 lr 0.05 cs 0.9 es 30 md 5
# step 130 lr 0.05 cs 0.9 es 30 md 9
# step 131 lr 0.05 cs 0.9 es 30 md 10
# step 132 lr 0.05 cs 0.9 es 30 md 11
# step 133 lr 0.05 cs 0.9 es 40 md 3
# step 134 lr 0.05 cs 0.9 es 40 md 4
# step 135 lr 0.05 cs 0.9 es 40 md 5
# step 136 lr 0.05 cs 0.9 es 40 md 9
# step 137 lr 0.05 cs 0.9 es 40 md 10
# step 138 lr 0.05 cs 0.9 es 40 md 11
# step 139 lr 0.05 cs 0.9 es 45 md 3
# step 140 lr 0.05 cs 0.9 es 45 md 4
# step 141 lr 0.05 cs 0.9 es 45 md 5
# step 142 lr 0.05 cs 0.9 es 45 md 9
# step 143 lr 0.05 cs 0.9 es 45 md 10
# step 144 lr 0.05 cs 0.9 es 45 md 11
# step 145 lr 0.05 cs 0.95 es 5 md 3
# step 146 lr 0.05 cs 0.95 es 5 md 4
# step 147 lr 0.05 cs 0.95 es 5 md 5
# step 148 lr 0.05 cs 0.95 es 5 md 9
# step 149 lr 0.05 cs 0.95 es 5 md 10
# step 150 lr 0.05 cs 0.95 es 5 md 11
# step 151 lr 0.05 cs 0.95 es 10 md 3
# step 152 lr 0.05 cs 0.95 es 10 md 4
# step 153 lr 0.05 cs 0.95 es 10 md 5
# step 154 lr 0.05 cs 0.95 es 10 md 9
# step 155 lr 0.05 cs 0.95 es 10 md 10
# step 156 lr 0.05 cs 0.95 es 10 md 11
# step 157 lr 0.05 cs 0.95 es 15 md 3
# step 158 lr 0.05 cs 0.95 es 15 md 4
# step 159 lr 0.05 cs 0.95 es 15 md 5
# step 160 lr 0.05 cs 0.95 es 15 md 9
# step 161 lr 0.05 cs 0.95 es 15 md 10
# step 162 lr 0.05 cs 0.95 es 15 md 11
# step 163 lr 0.05 cs 0.95 es 30 md 3
# step 164 lr 0.05 cs 0.95 es 30 md 4
# step 165 lr 0.05 cs 0.95 es 30 md 5
# step 166 lr 0.05 cs 0.95 es 30 md 9
# step 167 lr 0.05 cs 0.95 es 30 md 10
# step 168 lr 0.05 cs 0.95 es 30 md 11
# step 169 lr 0.05 cs 0.95 es 40 md 3
# step 170 lr 0.05 cs 0.95 es 40 md 4
# step 171 lr 0.05 cs 0.95 es 40 md 5
# step 172 lr 0.05 cs 0.95 es 40 md 9
# step 173 lr 0.05 cs 0.95 es 40 md 10
# step 174 lr 0.05 cs 0.95 es 40 md 11
# step 175 lr 0.05 cs 0.95 es 45 md 3
# step 176 lr 0.05 cs 0.95 es 45 md 4
# step 177 lr 0.05 cs 0.95 es 45 md 5
# step 178 lr 0.05 cs 0.95 es 45 md 9
# step 179 lr 0.05 cs 0.95 es 45 md 10
# step 180 lr 0.05 cs 0.95 es 45 md 11
# step 181 lr 0.01 cs 0.6 es 5 md 3
# step 182 lr 0.01 cs 0.6 es 5 md 4
# step 183 lr 0.01 cs 0.6 es 5 md 5
# step 184 lr 0.01 cs 0.6 es 5 md 9
# step 185 lr 0.01 cs 0.6 es 5 md 10
# step 186 lr 0.01 cs 0.6 es 5 md 11
# step 187 lr 0.01 cs 0.6 es 10 md 3
# step 188 lr 0.01 cs 0.6 es 10 md 4
# step 189 lr 0.01 cs 0.6 es 10 md 5
# step 190 lr 0.01 cs 0.6 es 10 md 9
# step 191 lr 0.01 cs 0.6 es 10 md 10
# step 192 lr 0.01 cs 0.6 es 10 md 11
# step 193 lr 0.01 cs 0.6 es 15 md 3
# step 194 lr 0.01 cs 0.6 es 15 md 4
# step 195 lr 0.01 cs 0.6 es 15 md 5
# step 196 lr 0.01 cs 0.6 es 15 md 9
# step 197 lr 0.01 cs 0.6 es 15 md 10
# step 198 lr 0.01 cs 0.6 es 15 md 11
# step 199 lr 0.01 cs 0.6 es 30 md 3
# step 200 lr 0.01 cs 0.6 es 30 md 4
# step 201 lr 0.01 cs 0.6 es 30 md 5
# step 202 lr 0.01 cs 0.6 es 30 md 9
# step 203 lr 0.01 cs 0.6 es 30 md 10
# step 204 lr 0.01 cs 0.6 es 30 md 11
# step 205 lr 0.01 cs 0.6 es 40 md 3
# step 206 lr 0.01 cs 0.6 es 40 md 4
# step 207 lr 0.01 cs 0.6 es 40 md 5
# step 208 lr 0.01 cs 0.6 es 40 md 9
# step 209 lr 0.01 cs 0.6 es 40 md 10
# step 210 lr 0.01 cs 0.6 es 40 md 11
# step 211 lr 0.01 cs 0.6 es 45 md 3
# step 212 lr 0.01 cs 0.6 es 45 md 4
# step 213 lr 0.01 cs 0.6 es 45 md 5
# step 214 lr 0.01 cs 0.6 es 45 md 9
# step 215 lr 0.01 cs 0.6 es 45 md 10
# step 216 lr 0.01 cs 0.6 es 45 md 11
# step 217 lr 0.01 cs 0.7 es 5 md 3
# step 218 lr 0.01 cs 0.7 es 5 md 4
# step 219 lr 0.01 cs 0.7 es 5 md 5
# step 220 lr 0.01 cs 0.7 es 5 md 9
# step 221 lr 0.01 cs 0.7 es 5 md 10
# step 222 lr 0.01 cs 0.7 es 5 md 11
# step 223 lr 0.01 cs 0.7 es 10 md 3
# step 224 lr 0.01 cs 0.7 es 10 md 4
# step 225 lr 0.01 cs 0.7 es 10 md 5
# step 226 lr 0.01 cs 0.7 es 10 md 9
# step 227 lr 0.01 cs 0.7 es 10 md 10
# step 228 lr 0.01 cs 0.7 es 10 md 11
# step 229 lr 0.01 cs 0.7 es 15 md 3
# step 230 lr 0.01 cs 0.7 es 15 md 4
# step 231 lr 0.01 cs 0.7 es 15 md 5
# step 232 lr 0.01 cs 0.7 es 15 md 9
# step 233 lr 0.01 cs 0.7 es 15 md 10
# step 234 lr 0.01 cs 0.7 es 15 md 11
# step 235 lr 0.01 cs 0.7 es 30 md 3
# step 236 lr 0.01 cs 0.7 es 30 md 4
# step 237 lr 0.01 cs 0.7 es 30 md 5
# step 238 lr 0.01 cs 0.7 es 30 md 9
# step 239 lr 0.01 cs 0.7 es 30 md 10
# step 240 lr 0.01 cs 0.7 es 30 md 11
# step 241 lr 0.01 cs 0.7 es 40 md 3
# step 242 lr 0.01 cs 0.7 es 40 md 4
# step 243 lr 0.01 cs 0.7 es 40 md 5
# step 244 lr 0.01 cs 0.7 es 40 md 9
# step 245 lr 0.01 cs 0.7 es 40 md 10
# step 246 lr 0.01 cs 0.7 es 40 md 11
# step 247 lr 0.01 cs 0.7 es 45 md 3
# step 248 lr 0.01 cs 0.7 es 45 md 4
# step 249 lr 0.01 cs 0.7 es 45 md 5
# step 250 lr 0.01 cs 0.7 es 45 md 9
# step 251 lr 0.01 cs 0.7 es 45 md 10
# step 252 lr 0.01 cs 0.7 es 45 md 11
# step 253 lr 0.01 cs 0.8 es 5 md 3
# step 254 lr 0.01 cs 0.8 es 5 md 4
# step 255 lr 0.01 cs 0.8 es 5 md 5
# step 256 lr 0.01 cs 0.8 es 5 md 9
# step 257 lr 0.01 cs 0.8 es 5 md 10
# step 258 lr 0.01 cs 0.8 es 5 md 11
# step 259 lr 0.01 cs 0.8 es 10 md 3
# step 260 lr 0.01 cs 0.8 es 10 md 4
# step 261 lr 0.01 cs 0.8 es 10 md 5
# step 262 lr 0.01 cs 0.8 es 10 md 9
# step 263 lr 0.01 cs 0.8 es 10 md 10
# step 264 lr 0.01 cs 0.8 es 10 md 11
# step 265 lr 0.01 cs 0.8 es 15 md 3
# step 266 lr 0.01 cs 0.8 es 15 md 4
# step 267 lr 0.01 cs 0.8 es 15 md 5
# step 268 lr 0.01 cs 0.8 es 15 md 9
# step 269 lr 0.01 cs 0.8 es 15 md 10
# step 270 lr 0.01 cs 0.8 es 15 md 11
# step 271 lr 0.01 cs 0.8 es 30 md 3
# step 272 lr 0.01 cs 0.8 es 30 md 4
# step 273 lr 0.01 cs 0.8 es 30 md 5
# step 274 lr 0.01 cs 0.8 es 30 md 9
# step 275 lr 0.01 cs 0.8 es 30 md 10
# step 276 lr 0.01 cs 0.8 es 30 md 11
# step 277 lr 0.01 cs 0.8 es 40 md 3
# step 278 lr 0.01 cs 0.8 es 40 md 4
# step 279 lr 0.01 cs 0.8 es 40 md 5
# step 280 lr 0.01 cs 0.8 es 40 md 9
# step 281 lr 0.01 cs 0.8 es 40 md 10
# step 282 lr 0.01 cs 0.8 es 40 md 11
# step 283 lr 0.01 cs 0.8 es 45 md 3
# step 284 lr 0.01 cs 0.8 es 45 md 4
# step 285 lr 0.01 cs 0.8 es 45 md 5
# step 286 lr 0.01 cs 0.8 es 45 md 9
# step 287 lr 0.01 cs 0.8 es 45 md 10
# step 288 lr 0.01 cs 0.8 es 45 md 11
# step 289 lr 0.01 cs 0.9 es 5 md 3
# step 290 lr 0.01 cs 0.9 es 5 md 4
# step 291 lr 0.01 cs 0.9 es 5 md 5
# step 292 lr 0.01 cs 0.9 es 5 md 9
# step 293 lr 0.01 cs 0.9 es 5 md 10
# step 294 lr 0.01 cs 0.9 es 5 md 11
# step 295 lr 0.01 cs 0.9 es 10 md 3
# step 296 lr 0.01 cs 0.9 es 10 md 4
# step 297 lr 0.01 cs 0.9 es 10 md 5
# step 298 lr 0.01 cs 0.9 es 10 md 9
# step 299 lr 0.01 cs 0.9 es 10 md 10
# step 300 lr 0.01 cs 0.9 es 10 md 11
# step 301 lr 0.01 cs 0.9 es 15 md 3
# step 302 lr 0.01 cs 0.9 es 15 md 4
# step 303 lr 0.01 cs 0.9 es 15 md 5
# step 304 lr 0.01 cs 0.9 es 15 md 9
# step 305 lr 0.01 cs 0.9 es 15 md 10
# step 306 lr 0.01 cs 0.9 es 15 md 11
# step 307 lr 0.01 cs 0.9 es 30 md 3
# step 308 lr 0.01 cs 0.9 es 30 md 4
# step 309 lr 0.01 cs 0.9 es 30 md 5
# step 310 lr 0.01 cs 0.9 es 30 md 9
# step 311 lr 0.01 cs 0.9 es 30 md 10
# step 312 lr 0.01 cs 0.9 es 30 md 11
# step 313 lr 0.01 cs 0.9 es 40 md 3
# step 314 lr 0.01 cs 0.9 es 40 md 4
# step 315 lr 0.01 cs 0.9 es 40 md 5
# step 316 lr 0.01 cs 0.9 es 40 md 9
# step 317 lr 0.01 cs 0.9 es 40 md 10
# step 318 lr 0.01 cs 0.9 es 40 md 11
# step 319 lr 0.01 cs 0.9 es 45 md 3
# step 320 lr 0.01 cs 0.9 es 45 md 4
# step 321 lr 0.01 cs 0.9 es 45 md 5
# step 322 lr 0.01 cs 0.9 es 45 md 9
# step 323 lr 0.01 cs 0.9 es 45 md 10
# step 324 lr 0.01 cs 0.9 es 45 md 11
# step 325 lr 0.01 cs 0.95 es 5 md 3
# step 326 lr 0.01 cs 0.95 es 5 md 4
# step 327 lr 0.01 cs 0.95 es 5 md 5
# step 328 lr 0.01 cs 0.95 es 5 md 9
# step 329 lr 0.01 cs 0.95 es 5 md 10
# step 330 lr 0.01 cs 0.95 es 5 md 11
# step 331 lr 0.01 cs 0.95 es 10 md 3
# step 332 lr 0.01 cs 0.95 es 10 md 4
# step 333 lr 0.01 cs 0.95 es 10 md 5
# step 334 lr 0.01 cs 0.95 es 10 md 9
# step 335 lr 0.01 cs 0.95 es 10 md 10
# step 336 lr 0.01 cs 0.95 es 10 md 11
# step 337 lr 0.01 cs 0.95 es 15 md 3
# step 338 lr 0.01 cs 0.95 es 15 md 4
# step 339 lr 0.01 cs 0.95 es 15 md 5
# step 340 lr 0.01 cs 0.95 es 15 md 9
# step 341 lr 0.01 cs 0.95 es 15 md 10
# step 342 lr 0.01 cs 0.95 es 15 md 11
# step 343 lr 0.01 cs 0.95 es 30 md 3
# step 344 lr 0.01 cs 0.95 es 30 md 4
# step 345 lr 0.01 cs 0.95 es 30 md 5
# step 346 lr 0.01 cs 0.95 es 30 md 9
# step 347 lr 0.01 cs 0.95 es 30 md 10
# step 348 lr 0.01 cs 0.95 es 30 md 11
# step 349 lr 0.01 cs 0.95 es 40 md 3
# step 350 lr 0.01 cs 0.95 es 40 md 4
# step 351 lr 0.01 cs 0.95 es 40 md 5
# step 352 lr 0.01 cs 0.95 es 40 md 9
# step 353 lr 0.01 cs 0.95 es 40 md 10
# step 354 lr 0.01 cs 0.95 es 40 md 11
# step 355 lr 0.01 cs 0.95 es 45 md 3
# step 356 lr 0.01 cs 0.95 es 45 md 4
# step 357 lr 0.01 cs 0.95 es 45 md 5
# step 358 lr 0.01 cs 0.95 es 45 md 9
# step 359 lr 0.01 cs 0.95 es 45 md 10
# step 360 lr 0.01 cs 0.95 es 45 md 11
# step 361 lr 0.1 cs 0.6 es 5 md 3
# step 362 lr 0.1 cs 0.6 es 5 md 4
# step 363 lr 0.1 cs 0.6 es 5 md 5
# step 364 lr 0.1 cs 0.6 es 5 md 9
# step 365 lr 0.1 cs 0.6 es 5 md 10
# step 366 lr 0.1 cs 0.6 es 5 md 11
# step 367 lr 0.1 cs 0.6 es 10 md 3
# step 368 lr 0.1 cs 0.6 es 10 md 4
# step 369 lr 0.1 cs 0.6 es 10 md 5
# step 370 lr 0.1 cs 0.6 es 10 md 9
# step 371 lr 0.1 cs 0.6 es 10 md 10
# step 372 lr 0.1 cs 0.6 es 10 md 11
# step 373 lr 0.1 cs 0.6 es 15 md 3
# step 374 lr 0.1 cs 0.6 es 15 md 4
# step 375 lr 0.1 cs 0.6 es 15 md 5
# step 376 lr 0.1 cs 0.6 es 15 md 9
# step 377 lr 0.1 cs 0.6 es 15 md 10
# step 378 lr 0.1 cs 0.6 es 15 md 11
# step 379 lr 0.1 cs 0.6 es 30 md 3
# step 380 lr 0.1 cs 0.6 es 30 md 4
# step 381 lr 0.1 cs 0.6 es 30 md 5
# step 382 lr 0.1 cs 0.6 es 30 md 9
# step 383 lr 0.1 cs 0.6 es 30 md 10
# step 384 lr 0.1 cs 0.6 es 30 md 11
# step 385 lr 0.1 cs 0.6 es 40 md 3
# step 386 lr 0.1 cs 0.6 es 40 md 4
# step 387 lr 0.1 cs 0.6 es 40 md 5
# step 388 lr 0.1 cs 0.6 es 40 md 9
# step 389 lr 0.1 cs 0.6 es 40 md 10
# step 390 lr 0.1 cs 0.6 es 40 md 11
# step 391 lr 0.1 cs 0.6 es 45 md 3
# step 392 lr 0.1 cs 0.6 es 45 md 4
# step 393 lr 0.1 cs 0.6 es 45 md 5
# step 394 lr 0.1 cs 0.6 es 45 md 9
# step 395 lr 0.1 cs 0.6 es 45 md 10
# step 396 lr 0.1 cs 0.6 es 45 md 11
# step 397 lr 0.1 cs 0.7 es 5 md 3
# step 398 lr 0.1 cs 0.7 es 5 md 4
# step 399 lr 0.1 cs 0.7 es 5 md 5
# step 400 lr 0.1 cs 0.7 es 5 md 9
# step 401 lr 0.1 cs 0.7 es 5 md 10
# step 402 lr 0.1 cs 0.7 es 5 md 11
# step 403 lr 0.1 cs 0.7 es 10 md 3
# step 404 lr 0.1 cs 0.7 es 10 md 4
# step 405 lr 0.1 cs 0.7 es 10 md 5
# step 406 lr 0.1 cs 0.7 es 10 md 9
# step 407 lr 0.1 cs 0.7 es 10 md 10
# step 408 lr 0.1 cs 0.7 es 10 md 11
# step 409 lr 0.1 cs 0.7 es 15 md 3
# step 410 lr 0.1 cs 0.7 es 15 md 4
# step 411 lr 0.1 cs 0.7 es 15 md 5
# step 412 lr 0.1 cs 0.7 es 15 md 9
# step 413 lr 0.1 cs 0.7 es 15 md 10
# step 414 lr 0.1 cs 0.7 es 15 md 11
# step 415 lr 0.1 cs 0.7 es 30 md 3
# step 416 lr 0.1 cs 0.7 es 30 md 4
# step 417 lr 0.1 cs 0.7 es 30 md 5
# step 418 lr 0.1 cs 0.7 es 30 md 9
# step 419 lr 0.1 cs 0.7 es 30 md 10
# step 420 lr 0.1 cs 0.7 es 30 md 11
# step 421 lr 0.1 cs 0.7 es 40 md 3
# step 422 lr 0.1 cs 0.7 es 40 md 4
# step 423 lr 0.1 cs 0.7 es 40 md 5
# step 424 lr 0.1 cs 0.7 es 40 md 9
# step 425 lr 0.1 cs 0.7 es 40 md 10
# step 426 lr 0.1 cs 0.7 es 40 md 11
# step 427 lr 0.1 cs 0.7 es 45 md 3
# step 428 lr 0.1 cs 0.7 es 45 md 4
# step 429 lr 0.1 cs 0.7 es 45 md 5
# step 430 lr 0.1 cs 0.7 es 45 md 9
# step 431 lr 0.1 cs 0.7 es 45 md 10
# step 432 lr 0.1 cs 0.7 es 45 md 11
# step 433 lr 0.1 cs 0.8 es 5 md 3
# step 434 lr 0.1 cs 0.8 es 5 md 4
# step 435 lr 0.1 cs 0.8 es 5 md 5
# step 436 lr 0.1 cs 0.8 es 5 md 9
# step 437 lr 0.1 cs 0.8 es 5 md 10
# step 438 lr 0.1 cs 0.8 es 5 md 11
# step 439 lr 0.1 cs 0.8 es 10 md 3
# step 440 lr 0.1 cs 0.8 es 10 md 4
# step 441 lr 0.1 cs 0.8 es 10 md 5
# step 442 lr 0.1 cs 0.8 es 10 md 9
# step 443 lr 0.1 cs 0.8 es 10 md 10
# step 444 lr 0.1 cs 0.8 es 10 md 11
# step 445 lr 0.1 cs 0.8 es 15 md 3
# step 446 lr 0.1 cs 0.8 es 15 md 4
# step 447 lr 0.1 cs 0.8 es 15 md 5
# step 448 lr 0.1 cs 0.8 es 15 md 9
# step 449 lr 0.1 cs 0.8 es 15 md 10
# step 450 lr 0.1 cs 0.8 es 15 md 11
# step 451 lr 0.1 cs 0.8 es 30 md 3
# step 452 lr 0.1 cs 0.8 es 30 md 4
# step 453 lr 0.1 cs 0.8 es 30 md 5
# step 454 lr 0.1 cs 0.8 es 30 md 9
# step 455 lr 0.1 cs 0.8 es 30 md 10
# step 456 lr 0.1 cs 0.8 es 30 md 11
# step 457 lr 0.1 cs 0.8 es 40 md 3
# step 458 lr 0.1 cs 0.8 es 40 md 4
# step 459 lr 0.1 cs 0.8 es 40 md 5
# step 460 lr 0.1 cs 0.8 es 40 md 9
# step 461 lr 0.1 cs 0.8 es 40 md 10
# step 462 lr 0.1 cs 0.8 es 40 md 11
# step 463 lr 0.1 cs 0.8 es 45 md 3
# step 464 lr 0.1 cs 0.8 es 45 md 4
# step 465 lr 0.1 cs 0.8 es 45 md 5
# step 466 lr 0.1 cs 0.8 es 45 md 9
# step 467 lr 0.1 cs 0.8 es 45 md 10
# step 468 lr 0.1 cs 0.8 es 45 md 11
# step 469 lr 0.1 cs 0.9 es 5 md 3
# step 470 lr 0.1 cs 0.9 es 5 md 4
# step 471 lr 0.1 cs 0.9 es 5 md 5
# step 472 lr 0.1 cs 0.9 es 5 md 9
# step 473 lr 0.1 cs 0.9 es 5 md 10
# step 474 lr 0.1 cs 0.9 es 5 md 11
# step 475 lr 0.1 cs 0.9 es 10 md 3
# step 476 lr 0.1 cs 0.9 es 10 md 4
# step 477 lr 0.1 cs 0.9 es 10 md 5
# step 478 lr 0.1 cs 0.9 es 10 md 9
# step 479 lr 0.1 cs 0.9 es 10 md 10
# step 480 lr 0.1 cs 0.9 es 10 md 11
# step 481 lr 0.1 cs 0.9 es 15 md 3
# step 482 lr 0.1 cs 0.9 es 15 md 4
# step 483 lr 0.1 cs 0.9 es 15 md 5
# step 484 lr 0.1 cs 0.9 es 15 md 9
# step 485 lr 0.1 cs 0.9 es 15 md 10
# step 486 lr 0.1 cs 0.9 es 15 md 11
# step 487 lr 0.1 cs 0.9 es 30 md 3
# step 488 lr 0.1 cs 0.9 es 30 md 4
# step 489 lr 0.1 cs 0.9 es 30 md 5
# step 490 lr 0.1 cs 0.9 es 30 md 9
# step 491 lr 0.1 cs 0.9 es 30 md 10
# step 492 lr 0.1 cs 0.9 es 30 md 11
# step 493 lr 0.1 cs 0.9 es 40 md 3
# step 494 lr 0.1 cs 0.9 es 40 md 4
# step 495 lr 0.1 cs 0.9 es 40 md 5
# step 496 lr 0.1 cs 0.9 es 40 md 9
# step 497 lr 0.1 cs 0.9 es 40 md 10
# step 498 lr 0.1 cs 0.9 es 40 md 11
# step 499 lr 0.1 cs 0.9 es 45 md 3
# step 500 lr 0.1 cs 0.9 es 45 md 4
# step 501 lr 0.1 cs 0.9 es 45 md 5
# step 502 lr 0.1 cs 0.9 es 45 md 9
# step 503 lr 0.1 cs 0.9 es 45 md 10
# step 504 lr 0.1 cs 0.9 es 45 md 11
# step 505 lr 0.1 cs 0.95 es 5 md 3
# step 506 lr 0.1 cs 0.95 es 5 md 4
# step 507 lr 0.1 cs 0.95 es 5 md 5
# step 508 lr 0.1 cs 0.95 es 5 md 9
# step 509 lr 0.1 cs 0.95 es 5 md 10
# step 510 lr 0.1 cs 0.95 es 5 md 11
# step 511 lr 0.1 cs 0.95 es 10 md 3
# step 512 lr 0.1 cs 0.95 es 10 md 4
# step 513 lr 0.1 cs 0.95 es 10 md 5
# step 514 lr 0.1 cs 0.95 es 10 md 9
# step 515 lr 0.1 cs 0.95 es 10 md 10
# step 516 lr 0.1 cs 0.95 es 10 md 11
# step 517 lr 0.1 cs 0.95 es 15 md 3
# step 518 lr 0.1 cs 0.95 es 15 md 4
# step 519 lr 0.1 cs 0.95 es 15 md 5
# step 520 lr 0.1 cs 0.95 es 15 md 9
# step 521 lr 0.1 cs 0.95 es 15 md 10
# step 522 lr 0.1 cs 0.95 es 15 md 11
# step 523 lr 0.1 cs 0.95 es 30 md 3
# step 524 lr 0.1 cs 0.95 es 30 md 4
# step 525 lr 0.1 cs 0.95 es 30 md 5
# step 526 lr 0.1 cs 0.95 es 30 md 9
# step 527 lr 0.1 cs 0.95 es 30 md 10
# step 528 lr 0.1 cs 0.95 es 30 md 11
# step 529 lr 0.1 cs 0.95 es 40 md 3
# step 530 lr 0.1 cs 0.95 es 40 md 4
# step 531 lr 0.1 cs 0.95 es 40 md 5
# step 532 lr 0.1 cs 0.95 es 40 md 9
# step 533 lr 0.1 cs 0.95 es 40 md 10
# step 534 lr 0.1 cs 0.95 es 40 md 11
# step 535 lr 0.1 cs 0.95 es 45 md 3
# step 536 lr 0.1 cs 0.95 es 45 md 4
# step 537 lr 0.1 cs 0.95 es 45 md 5
# step 538 lr 0.1 cs 0.95 es 45 md 9
# step 539 lr 0.1 cs 0.95 es 45 md 10
# step 540 lr 0.1 cs 0.95 es 45 md 11
# step 541 lr 0.2 cs 0.6 es 5 md 3
# step 542 lr 0.2 cs 0.6 es 5 md 4
# step 543 lr 0.2 cs 0.6 es 5 md 5
# step 544 lr 0.2 cs 0.6 es 5 md 9
# step 545 lr 0.2 cs 0.6 es 5 md 10
# step 546 lr 0.2 cs 0.6 es 5 md 11
# step 547 lr 0.2 cs 0.6 es 10 md 3
# step 548 lr 0.2 cs 0.6 es 10 md 4
# step 549 lr 0.2 cs 0.6 es 10 md 5
# step 550 lr 0.2 cs 0.6 es 10 md 9
# step 551 lr 0.2 cs 0.6 es 10 md 10
# step 552 lr 0.2 cs 0.6 es 10 md 11
# step 553 lr 0.2 cs 0.6 es 15 md 3
# step 554 lr 0.2 cs 0.6 es 15 md 4
# step 555 lr 0.2 cs 0.6 es 15 md 5
# step 556 lr 0.2 cs 0.6 es 15 md 9
# step 557 lr 0.2 cs 0.6 es 15 md 10
# step 558 lr 0.2 cs 0.6 es 15 md 11
# step 559 lr 0.2 cs 0.6 es 30 md 3
# step 560 lr 0.2 cs 0.6 es 30 md 4
# step 561 lr 0.2 cs 0.6 es 30 md 5
# step 562 lr 0.2 cs 0.6 es 30 md 9
# step 563 lr 0.2 cs 0.6 es 30 md 10
# step 564 lr 0.2 cs 0.6 es 30 md 11
# step 565 lr 0.2 cs 0.6 es 40 md 3
# step 566 lr 0.2 cs 0.6 es 40 md 4
# step 567 lr 0.2 cs 0.6 es 40 md 5
# step 568 lr 0.2 cs 0.6 es 40 md 9
# step 569 lr 0.2 cs 0.6 es 40 md 10
# step 570 lr 0.2 cs 0.6 es 40 md 11
# step 571 lr 0.2 cs 0.6 es 45 md 3
# step 572 lr 0.2 cs 0.6 es 45 md 4
# step 573 lr 0.2 cs 0.6 es 45 md 5
# step 574 lr 0.2 cs 0.6 es 45 md 9
# step 575 lr 0.2 cs 0.6 es 45 md 10
# step 576 lr 0.2 cs 0.6 es 45 md 11
# step 577 lr 0.2 cs 0.7 es 5 md 3
# step 578 lr 0.2 cs 0.7 es 5 md 4
# step 579 lr 0.2 cs 0.7 es 5 md 5
# step 580 lr 0.2 cs 0.7 es 5 md 9
# step 581 lr 0.2 cs 0.7 es 5 md 10
# step 582 lr 0.2 cs 0.7 es 5 md 11
# step 583 lr 0.2 cs 0.7 es 10 md 3
# step 584 lr 0.2 cs 0.7 es 10 md 4
# step 585 lr 0.2 cs 0.7 es 10 md 5
# step 586 lr 0.2 cs 0.7 es 10 md 9
# step 587 lr 0.2 cs 0.7 es 10 md 10
# step 588 lr 0.2 cs 0.7 es 10 md 11
# step 589 lr 0.2 cs 0.7 es 15 md 3
# step 590 lr 0.2 cs 0.7 es 15 md 4
# step 591 lr 0.2 cs 0.7 es 15 md 5
# step 592 lr 0.2 cs 0.7 es 15 md 9
# step 593 lr 0.2 cs 0.7 es 15 md 10
# step 594 lr 0.2 cs 0.7 es 15 md 11
# step 595 lr 0.2 cs 0.7 es 30 md 3
# step 596 lr 0.2 cs 0.7 es 30 md 4
# step 597 lr 0.2 cs 0.7 es 30 md 5
# step 598 lr 0.2 cs 0.7 es 30 md 9
# step 599 lr 0.2 cs 0.7 es 30 md 10
# step 600 lr 0.2 cs 0.7 es 30 md 11
# step 601 lr 0.2 cs 0.7 es 40 md 3
# step 602 lr 0.2 cs 0.7 es 40 md 4
# step 603 lr 0.2 cs 0.7 es 40 md 5
# step 604 lr 0.2 cs 0.7 es 40 md 9
# step 605 lr 0.2 cs 0.7 es 40 md 10
# step 606 lr 0.2 cs 0.7 es 40 md 11
# step 607 lr 0.2 cs 0.7 es 45 md 3
# step 608 lr 0.2 cs 0.7 es 45 md 4
# step 609 lr 0.2 cs 0.7 es 45 md 5
# step 610 lr 0.2 cs 0.7 es 45 md 9
# step 611 lr 0.2 cs 0.7 es 45 md 10
# step 612 lr 0.2 cs 0.7 es 45 md 11
# step 613 lr 0.2 cs 0.8 es 5 md 3
# step 614 lr 0.2 cs 0.8 es 5 md 4
# step 615 lr 0.2 cs 0.8 es 5 md 5
# step 616 lr 0.2 cs 0.8 es 5 md 9
# step 617 lr 0.2 cs 0.8 es 5 md 10
# step 618 lr 0.2 cs 0.8 es 5 md 11
# step 619 lr 0.2 cs 0.8 es 10 md 3
# step 620 lr 0.2 cs 0.8 es 10 md 4
# step 621 lr 0.2 cs 0.8 es 10 md 5
# step 622 lr 0.2 cs 0.8 es 10 md 9
# step 623 lr 0.2 cs 0.8 es 10 md 10
# step 624 lr 0.2 cs 0.8 es 10 md 11
# step 625 lr 0.2 cs 0.8 es 15 md 3
# step 626 lr 0.2 cs 0.8 es 15 md 4
# step 627 lr 0.2 cs 0.8 es 15 md 5
# step 628 lr 0.2 cs 0.8 es 15 md 9
# step 629 lr 0.2 cs 0.8 es 15 md 10
# step 630 lr 0.2 cs 0.8 es 15 md 11
# step 631 lr 0.2 cs 0.8 es 30 md 3
# step 632 lr 0.2 cs 0.8 es 30 md 4
# step 633 lr 0.2 cs 0.8 es 30 md 5
# step 634 lr 0.2 cs 0.8 es 30 md 9
# step 635 lr 0.2 cs 0.8 es 30 md 10
# step 636 lr 0.2 cs 0.8 es 30 md 11
# step 637 lr 0.2 cs 0.8 es 40 md 3
# step 638 lr 0.2 cs 0.8 es 40 md 4
# step 639 lr 0.2 cs 0.8 es 40 md 5
# step 640 lr 0.2 cs 0.8 es 40 md 9
# step 641 lr 0.2 cs 0.8 es 40 md 10
# step 642 lr 0.2 cs 0.8 es 40 md 11
# step 643 lr 0.2 cs 0.8 es 45 md 3
# step 644 lr 0.2 cs 0.8 es 45 md 4
# step 645 lr 0.2 cs 0.8 es 45 md 5
# step 646 lr 0.2 cs 0.8 es 45 md 9
# step 647 lr 0.2 cs 0.8 es 45 md 10
# step 648 lr 0.2 cs 0.8 es 45 md 11
# step 649 lr 0.2 cs 0.9 es 5 md 3
# step 650 lr 0.2 cs 0.9 es 5 md 4
# step 651 lr 0.2 cs 0.9 es 5 md 5
# step 652 lr 0.2 cs 0.9 es 5 md 9
# step 653 lr 0.2 cs 0.9 es 5 md 10
# step 654 lr 0.2 cs 0.9 es 5 md 11
# step 655 lr 0.2 cs 0.9 es 10 md 3
# step 656 lr 0.2 cs 0.9 es 10 md 4
# step 657 lr 0.2 cs 0.9 es 10 md 5
# step 658 lr 0.2 cs 0.9 es 10 md 9
# step 659 lr 0.2 cs 0.9 es 10 md 10
# step 660 lr 0.2 cs 0.9 es 10 md 11
# step 661 lr 0.2 cs 0.9 es 15 md 3
# step 662 lr 0.2 cs 0.9 es 15 md 4
# step 663 lr 0.2 cs 0.9 es 15 md 5
# step 664 lr 0.2 cs 0.9 es 15 md 9
# step 665 lr 0.2 cs 0.9 es 15 md 10
# step 666 lr 0.2 cs 0.9 es 15 md 11
# step 667 lr 0.2 cs 0.9 es 30 md 3
# step 668 lr 0.2 cs 0.9 es 30 md 4
# step 669 lr 0.2 cs 0.9 es 30 md 5
# step 670 lr 0.2 cs 0.9 es 30 md 9
# step 671 lr 0.2 cs 0.9 es 30 md 10
# step 672 lr 0.2 cs 0.9 es 30 md 11
# step 673 lr 0.2 cs 0.9 es 40 md 3
# step 674 lr 0.2 cs 0.9 es 40 md 4
# step 675 lr 0.2 cs 0.9 es 40 md 5
# step 676 lr 0.2 cs 0.9 es 40 md 9
# step 677 lr 0.2 cs 0.9 es 40 md 10
# step 678 lr 0.2 cs 0.9 es 40 md 11
# step 679 lr 0.2 cs 0.9 es 45 md 3
# step 680 lr 0.2 cs 0.9 es 45 md 4
# step 681 lr 0.2 cs 0.9 es 45 md 5
# step 682 lr 0.2 cs 0.9 es 45 md 9
# step 683 lr 0.2 cs 0.9 es 45 md 10
# step 684 lr 0.2 cs 0.9 es 45 md 11
# step 685 lr 0.2 cs 0.95 es 5 md 3
# step 686 lr 0.2 cs 0.95 es 5 md 4
# step 687 lr 0.2 cs 0.95 es 5 md 5
# step 688 lr 0.2 cs 0.95 es 5 md 9
# step 689 lr 0.2 cs 0.95 es 5 md 10
# step 690 lr 0.2 cs 0.95 es 5 md 11
# step 691 lr 0.2 cs 0.95 es 10 md 3
# step 692 lr 0.2 cs 0.95 es 10 md 4
# step 693 lr 0.2 cs 0.95 es 10 md 5
# step 694 lr 0.2 cs 0.95 es 10 md 9
# step 695 lr 0.2 cs 0.95 es 10 md 10
# step 696 lr 0.2 cs 0.95 es 10 md 11
# step 697 lr 0.2 cs 0.95 es 15 md 3
# step 698 lr 0.2 cs 0.95 es 15 md 4
# step 699 lr 0.2 cs 0.95 es 15 md 5
# step 700 lr 0.2 cs 0.95 es 15 md 9
# step 701 lr 0.2 cs 0.95 es 15 md 10
# step 702 lr 0.2 cs 0.95 es 15 md 11
# step 703 lr 0.2 cs 0.95 es 30 md 3
# step 704 lr 0.2 cs 0.95 es 30 md 4
# step 705 lr 0.2 cs 0.95 es 30 md 5
# step 706 lr 0.2 cs 0.95 es 30 md 9
# step 707 lr 0.2 cs 0.95 es 30 md 10
# step 708 lr 0.2 cs 0.95 es 30 md 11
# step 709 lr 0.2 cs 0.95 es 40 md 3
# step 710 lr 0.2 cs 0.95 es 40 md 4
# step 711 lr 0.2 cs 0.95 es 40 md 5
# step 712 lr 0.2 cs 0.95 es 40 md 9
# step 713 lr 0.2 cs 0.95 es 40 md 10
# step 714 lr 0.2 cs 0.95 es 40 md 11
# step 715 lr 0.2 cs 0.95 es 45 md 3
# step 716 lr 0.2 cs 0.95 es 45 md 4
# step 717 lr 0.2 cs 0.95 es 45 md 5
# step 718 lr 0.2 cs 0.95 es 45 md 9
# step 719 lr 0.2 cs 0.95 es 45 md 10
# step 720 lr 0.2 cs 0.95 es 45 md 11
# step 721 lr 0.25 cs 0.6 es 5 md 3
# step 722 lr 0.25 cs 0.6 es 5 md 4
# step 723 lr 0.25 cs 0.6 es 5 md 5
# step 724 lr 0.25 cs 0.6 es 5 md 9
# step 725 lr 0.25 cs 0.6 es 5 md 10
# step 726 lr 0.25 cs 0.6 es 5 md 11
# step 727 lr 0.25 cs 0.6 es 10 md 3
# step 728 lr 0.25 cs 0.6 es 10 md 4
# step 729 lr 0.25 cs 0.6 es 10 md 5
# step 730 lr 0.25 cs 0.6 es 10 md 9
# step 731 lr 0.25 cs 0.6 es 10 md 10
# step 732 lr 0.25 cs 0.6 es 10 md 11
# step 733 lr 0.25 cs 0.6 es 15 md 3
# step 734 lr 0.25 cs 0.6 es 15 md 4
# step 735 lr 0.25 cs 0.6 es 15 md 5
# step 736 lr 0.25 cs 0.6 es 15 md 9
# step 737 lr 0.25 cs 0.6 es 15 md 10
# step 738 lr 0.25 cs 0.6 es 15 md 11
# step 739 lr 0.25 cs 0.6 es 30 md 3
# step 740 lr 0.25 cs 0.6 es 30 md 4
# step 741 lr 0.25 cs 0.6 es 30 md 5
# step 742 lr 0.25 cs 0.6 es 30 md 9
# step 743 lr 0.25 cs 0.6 es 30 md 10
# step 744 lr 0.25 cs 0.6 es 30 md 11
# step 745 lr 0.25 cs 0.6 es 40 md 3
# step 746 lr 0.25 cs 0.6 es 40 md 4
# step 747 lr 0.25 cs 0.6 es 40 md 5
# step 748 lr 0.25 cs 0.6 es 40 md 9
# step 749 lr 0.25 cs 0.6 es 40 md 10
# step 750 lr 0.25 cs 0.6 es 40 md 11
# step 751 lr 0.25 cs 0.6 es 45 md 3
# step 752 lr 0.25 cs 0.6 es 45 md 4
# step 753 lr 0.25 cs 0.6 es 45 md 5
# step 754 lr 0.25 cs 0.6 es 45 md 9
# step 755 lr 0.25 cs 0.6 es 45 md 10
# step 756 lr 0.25 cs 0.6 es 45 md 11
# step 757 lr 0.25 cs 0.7 es 5 md 3
# step 758 lr 0.25 cs 0.7 es 5 md 4
# step 759 lr 0.25 cs 0.7 es 5 md 5
# step 760 lr 0.25 cs 0.7 es 5 md 9
# step 761 lr 0.25 cs 0.7 es 5 md 10
# step 762 lr 0.25 cs 0.7 es 5 md 11
# step 763 lr 0.25 cs 0.7 es 10 md 3
# step 764 lr 0.25 cs 0.7 es 10 md 4
# step 765 lr 0.25 cs 0.7 es 10 md 5
# step 766 lr 0.25 cs 0.7 es 10 md 9
# step 767 lr 0.25 cs 0.7 es 10 md 10
# step 768 lr 0.25 cs 0.7 es 10 md 11
# step 769 lr 0.25 cs 0.7 es 15 md 3
# step 770 lr 0.25 cs 0.7 es 15 md 4
# step 771 lr 0.25 cs 0.7 es 15 md 5
# step 772 lr 0.25 cs 0.7 es 15 md 9
# step 773 lr 0.25 cs 0.7 es 15 md 10
# step 774 lr 0.25 cs 0.7 es 15 md 11
# step 775 lr 0.25 cs 0.7 es 30 md 3
# step 776 lr 0.25 cs 0.7 es 30 md 4
# step 777 lr 0.25 cs 0.7 es 30 md 5
# step 778 lr 0.25 cs 0.7 es 30 md 9
# step 779 lr 0.25 cs 0.7 es 30 md 10
# step 780 lr 0.25 cs 0.7 es 30 md 11
# step 781 lr 0.25 cs 0.7 es 40 md 3
# step 782 lr 0.25 cs 0.7 es 40 md 4
# step 783 lr 0.25 cs 0.7 es 40 md 5
# step 784 lr 0.25 cs 0.7 es 40 md 9
# step 785 lr 0.25 cs 0.7 es 40 md 10
# step 786 lr 0.25 cs 0.7 es 40 md 11
# step 787 lr 0.25 cs 0.7 es 45 md 3
# step 788 lr 0.25 cs 0.7 es 45 md 4
# step 789 lr 0.25 cs 0.7 es 45 md 5
# step 790 lr 0.25 cs 0.7 es 45 md 9
# step 791 lr 0.25 cs 0.7 es 45 md 10
# step 792 lr 0.25 cs 0.7 es 45 md 11
# step 793 lr 0.25 cs 0.8 es 5 md 3
# step 794 lr 0.25 cs 0.8 es 5 md 4
# step 795 lr 0.25 cs 0.8 es 5 md 5
# step 796 lr 0.25 cs 0.8 es 5 md 9
# step 797 lr 0.25 cs 0.8 es 5 md 10
# step 798 lr 0.25 cs 0.8 es 5 md 11
# step 799 lr 0.25 cs 0.8 es 10 md 3
# step 800 lr 0.25 cs 0.8 es 10 md 4
# step 801 lr 0.25 cs 0.8 es 10 md 5
# step 802 lr 0.25 cs 0.8 es 10 md 9
# step 803 lr 0.25 cs 0.8 es 10 md 10
# step 804 lr 0.25 cs 0.8 es 10 md 11
# step 805 lr 0.25 cs 0.8 es 15 md 3
# step 806 lr 0.25 cs 0.8 es 15 md 4
# step 807 lr 0.25 cs 0.8 es 15 md 5
# step 808 lr 0.25 cs 0.8 es 15 md 9
# step 809 lr 0.25 cs 0.8 es 15 md 10
# step 810 lr 0.25 cs 0.8 es 15 md 11
# step 811 lr 0.25 cs 0.8 es 30 md 3
# step 812 lr 0.25 cs 0.8 es 30 md 4
# step 813 lr 0.25 cs 0.8 es 30 md 5
# step 814 lr 0.25 cs 0.8 es 30 md 9
# step 815 lr 0.25 cs 0.8 es 30 md 10
# step 816 lr 0.25 cs 0.8 es 30 md 11
# step 817 lr 0.25 cs 0.8 es 40 md 3
# step 818 lr 0.25 cs 0.8 es 40 md 4
# step 819 lr 0.25 cs 0.8 es 40 md 5
# step 820 lr 0.25 cs 0.8 es 40 md 9
# step 821 lr 0.25 cs 0.8 es 40 md 10
# step 822 lr 0.25 cs 0.8 es 40 md 11
# step 823 lr 0.25 cs 0.8 es 45 md 3
# step 824 lr 0.25 cs 0.8 es 45 md 4
# step 825 lr 0.25 cs 0.8 es 45 md 5
# step 826 lr 0.25 cs 0.8 es 45 md 9
# step 827 lr 0.25 cs 0.8 es 45 md 10
# step 828 lr 0.25 cs 0.8 es 45 md 11
# step 829 lr 0.25 cs 0.9 es 5 md 3
# step 830 lr 0.25 cs 0.9 es 5 md 4
# step 831 lr 0.25 cs 0.9 es 5 md 5
# step 832 lr 0.25 cs 0.9 es 5 md 9
# step 833 lr 0.25 cs 0.9 es 5 md 10
# step 834 lr 0.25 cs 0.9 es 5 md 11
# step 835 lr 0.25 cs 0.9 es 10 md 3
# step 836 lr 0.25 cs 0.9 es 10 md 4
# step 837 lr 0.25 cs 0.9 es 10 md 5
# step 838 lr 0.25 cs 0.9 es 10 md 9
# step 839 lr 0.25 cs 0.9 es 10 md 10
# step 840 lr 0.25 cs 0.9 es 10 md 11
# step 841 lr 0.25 cs 0.9 es 15 md 3
# step 842 lr 0.25 cs 0.9 es 15 md 4
# step 843 lr 0.25 cs 0.9 es 15 md 5
# step 844 lr 0.25 cs 0.9 es 15 md 9
# step 845 lr 0.25 cs 0.9 es 15 md 10
# step 846 lr 0.25 cs 0.9 es 15 md 11
# step 847 lr 0.25 cs 0.9 es 30 md 3
# step 848 lr 0.25 cs 0.9 es 30 md 4
# step 849 lr 0.25 cs 0.9 es 30 md 5
# step 850 lr 0.25 cs 0.9 es 30 md 9
# step 851 lr 0.25 cs 0.9 es 30 md 10
# step 852 lr 0.25 cs 0.9 es 30 md 11
# step 853 lr 0.25 cs 0.9 es 40 md 3
# step 854 lr 0.25 cs 0.9 es 40 md 4
# step 855 lr 0.25 cs 0.9 es 40 md 5
# step 856 lr 0.25 cs 0.9 es 40 md 9
# step 857 lr 0.25 cs 0.9 es 40 md 10
# step 858 lr 0.25 cs 0.9 es 40 md 11
# step 859 lr 0.25 cs 0.9 es 45 md 3
# step 860 lr 0.25 cs 0.9 es 45 md 4
# step 861 lr 0.25 cs 0.9 es 45 md 5
# step 862 lr 0.25 cs 0.9 es 45 md 9
# step 863 lr 0.25 cs 0.9 es 45 md 10
# step 864 lr 0.25 cs 0.9 es 45 md 11
# step 865 lr 0.25 cs 0.95 es 5 md 3
# step 866 lr 0.25 cs 0.95 es 5 md 4
# step 867 lr 0.25 cs 0.95 es 5 md 5
# step 868 lr 0.25 cs 0.95 es 5 md 9
# step 869 lr 0.25 cs 0.95 es 5 md 10
# step 870 lr 0.25 cs 0.95 es 5 md 11
# step 871 lr 0.25 cs 0.95 es 10 md 3
# step 872 lr 0.25 cs 0.95 es 10 md 4
# step 873 lr 0.25 cs 0.95 es 10 md 5
# step 874 lr 0.25 cs 0.95 es 10 md 9
# step 875 lr 0.25 cs 0.95 es 10 md 10
# step 876 lr 0.25 cs 0.95 es 10 md 11
# step 877 lr 0.25 cs 0.95 es 15 md 3
# step 878 lr 0.25 cs 0.95 es 15 md 4
# step 879 lr 0.25 cs 0.95 es 15 md 5
# step 880 lr 0.25 cs 0.95 es 15 md 9
# step 881 lr 0.25 cs 0.95 es 15 md 10
# step 882 lr 0.25 cs 0.95 es 15 md 11
# step 883 lr 0.25 cs 0.95 es 30 md 3
# step 884 lr 0.25 cs 0.95 es 30 md 4
# step 885 lr 0.25 cs 0.95 es 30 md 5
# step 886 lr 0.25 cs 0.95 es 30 md 9
# step 887 lr 0.25 cs 0.95 es 30 md 10
# step 888 lr 0.25 cs 0.95 es 30 md 11
# step 889 lr 0.25 cs 0.95 es 40 md 3
# step 890 lr 0.25 cs 0.95 es 40 md 4
# step 891 lr 0.25 cs 0.95 es 40 md 5
# step 892 lr 0.25 cs 0.95 es 40 md 9
# step 893 lr 0.25 cs 0.95 es 40 md 10
# step 894 lr 0.25 cs 0.95 es 40 md 11
# step 895 lr 0.25 cs 0.95 es 45 md 3
# step 896 lr 0.25 cs 0.95 es 45 md 4
# step 897 lr 0.25 cs 0.95 es 45 md 5
# step 898 lr 0.25 cs 0.95 es 45 md 9
# step 899 lr 0.25 cs 0.95 es 45 md 10
# step 900 lr 0.25 cs 0.95 es 45 md 11
# ** best model - lr 0.05 cs 0.9 es 15 md 3
# ** best MSE -  5.00960587445148

# %%
sj_test, iq_test, _, _ = preprocess_data_test('./data-processed/dengue_features_test.csv')
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-57-81d17981cbc3> in <module>
# ----> 1 sj_test, iq_test, _, _ = preprocess_data_test('./data-processed/dengue_features_test.csv')
#
# <ipython-input-51-1e8074e73020> in preprocess_data_test(data_path, labels_path)
#      35
#      36
# ---> 37     return sj_x, iq_x, sj_y, iq_y
#
# UnboundLocalError: local variable 'sj_y' referenced before assignment

# %%
sj_model = xgb.XGBRegressor(
    objective ='reg:linear',
    colsample_bytree = sj_param['colsample_bytree'], 
    learning_rate = sj_param['learning_rate'], 
    max_depth = sj_param['max_depth'], 
    n_estimators = sj_param['n_estimators']
)
iq_model = xgb.XGBRegressor(
    objective ='reg:linear',
    colsample_bytree = iq_param['colsample_bytree'], 
    learning_rate = iq_param['learning_rate'], 
    max_depth = iq_param['max_depth'], 
    n_estimators = iq_param['n_estimators']
)
sj_model.fit(sj_x, sj_y)
iq_model.fit(iq_x, iq_y)

sj_predict = sj_model.predict(sj_test)
iq_predict = iq_model.predict(iq_test)

# %%
test_df = pd.read_csv('./data-processed/dengue_features_test.csv')[['city', 'year', 'weekofyear']]

total_cases = pd.concat([pd.Series(sj_predict), pd.Series(iq_predict)])

total_cases.index = test_df.index
test_df['total_cases'] = total_cases.astype(int)

test_df.to_csv('./data-processed/benchmark.csv', index=False)

# %%
test_df['total_cases'].unique()
# Out:
# array([ 23,  19,  16,  20,  11,  61,  25,  41,  32,  34,  39,  31,  76,
#         50,  30,  38,  37,  51,  59,  35,  36,  27,  40,  15,  21,  22,
#         13,  12,  14,  77,  48,  33,  29,  44,  43,  57,  45,  24,  17,
#         66,  28,  54,  42,  46,  72, 144,  65, 146, 138,  49,  56,  83,
#         63,  68,  55,  71,  18,  58,   6,   8,   4,   1,   3,   2,   5,
#         10,   9,   7], dtype=int64)
